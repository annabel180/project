# %% [markdown]
# Solutioning pt 1
#
#
# 1.   Data exploration
# 2.   Data Preprocessing
# 3.   Baseline model

# %%
import numpy as np
import os
import skimage.io as io
import skimage.transform as trans
import numpy as np
import tensorflow
import keras
from keras.models import Sequential
from keras.models import *
from keras.layers import *
from keras.optimizers import *
from keras.callbacks import ModelCheckpoint, LearningRateScheduler
from keras import backend as keras
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
# !unzip Animals.zip -d ./Animals/
# Out:
# Archive:  Animals.zip
#   inflating: ./Animals/hen/10.jpeg
#   inflating: ./Animals/hen/100.jpeg
#   inflating: ./Animals/hen/1000.jpeg
#   inflating: ./Animals/hen/1001.jpeg
#   inflating: ./Animals/hen/1010.jpeg
#   inflating: ./Animals/hen/1013.jpeg
#   inflating: ./Animals/hen/1016.jpeg
#   inflating: ./Animals/hen/1017.jpeg
#   inflating: ./Animals/hen/1018.jpeg
#   inflating: ./Animals/hen/102.jpeg
#   inflating: ./Animals/hen/1020.jpeg
#   inflating: ./Animals/hen/1021.jpeg
#   inflating: ./Animals/hen/1023.jpeg
#   inflating: ./Animals/hen/1024.jpeg
#   inflating: ./Animals/hen/1026.jpeg
#   inflating: ./Animals/hen/1028.jpeg
#   inflating: ./Animals/hen/103.jpeg
#   inflating: ./Animals/hen/1030.jpeg
#   inflating: ./Animals/hen/1031.jpeg
#   inflating: ./Animals/hen/1032.jpeg
#   inflating: ./Animals/hen/1033.jpeg
#   inflating: ./Animals/hen/1034.jpeg
#   inflating: ./Animals/hen/1035.jpeg
#   inflating: ./Animals/hen/1039.jpeg
#   inflating: ./Animals/hen/1041.jpeg
#   inflating: ./Animals/hen/1042.jpeg
#   inflating: ./Animals/hen/1043.jpeg
#   inflating: ./Animals/hen/1044.jpeg
#   inflating: ./Animals/hen/1045.jpeg
#   inflating: ./Animals/hen/1047.jpeg
#   inflating: ./Animals/hen/1048.jpeg
#   inflating: ./Animals/hen/105.jpeg
#   inflating: ./Animals/hen/1050.jpeg
#   inflating: ./Animals/hen/1051.jpeg
#   inflating: ./Animals/hen/1052.jpeg
#   inflating: ./Animals/hen/1053.jpeg
#   inflating: ./Animals/hen/1054.jpeg
#   inflating: ./Animals/hen/1059.jpeg
#   inflating: ./Animals/hen/1068.jpeg
#   inflating: ./Animals/hen/1069.jpeg
#   inflating: ./Animals/hen/1074.jpeg
#   inflating: ./Animals/hen/1077.jpeg
#   inflating: ./Animals/hen/1079.jpeg
#   inflating: ./Animals/hen/108.jpeg
#   inflating: ./Animals/hen/1080.jpeg
#   inflating: ./Animals/hen/1085.jpeg
#   inflating: ./Animals/hen/109.jpeg
#   inflating: ./Animals/hen/1091.jpeg
#   inflating: ./Animals/hen/1092.jpeg
#   inflating: ./Animals/hen/1093.jpeg
#   inflating: ./Animals/hen/1096.jpeg
#   inflating: ./Animals/hen/1099.jpeg
#   inflating: ./Animals/hen/110.jpeg
#   inflating: ./Animals/hen/1103.jpeg
#   inflating: ./Animals/hen/1104.jpeg
#   inflating: ./Animals/hen/1105.jpeg
#   inflating: ./Animals/hen/1108.jpeg
#   inflating: ./Animals/hen/1109.jpeg
#   inflating: ./Animals/hen/111.jpeg
#   inflating: ./Animals/hen/1110.jpeg
#   inflating: ./Animals/hen/1113.jpeg
#   inflating: ./Animals/hen/1114.jpeg
#   inflating: ./Animals/hen/1115.jpeg
#   inflating: ./Animals/hen/1116.jpeg
#   inflating: ./Animals/hen/1117.jpeg
#   inflating: ./Animals/hen/112.jpeg
#   inflating: ./Animals/hen/1120.jpeg
#   inflating: ./Animals/hen/1124.jpeg
#   inflating: ./Animals/hen/1125.jpeg
#   inflating: ./Animals/hen/1130.jpeg
#   inflating: ./Animals/hen/1131.jpeg
#   inflating: ./Animals/hen/1132.jpeg
#   inflating: ./Animals/hen/1133.jpeg
#   inflating: ./Animals/hen/1135.jpeg
#   inflating: ./Animals/hen/1136.jpeg
#   inflating: ./Animals/hen/1137.jpeg
#   inflating: ./Animals/hen/1140.jpeg
#   inflating: ./Animals/hen/1141.jpeg
#   inflating: ./Animals/hen/1142.jpeg
#   inflating: ./Animals/hen/1143.jpeg
#   inflating: ./Animals/hen/1144.jpeg
#   inflating: ./Animals/hen/1147.jpeg
#   inflating: ./Animals/hen/1148.jpeg
#   inflating: ./Animals/hen/115.jpeg
#   inflating: ./Animals/hen/1150.jpeg
#   inflating: ./Animals/hen/1158.jpeg
#   inflating: ./Animals/hen/1159.jpeg
#   inflating: ./Animals/hen/1160.jpeg
#   inflating: ./Animals/hen/1162.jpeg
#   inflating: ./Animals/hen/1164.jpeg
#   inflating: ./Animals/hen/1165.jpeg
#   inflating: ./Animals/hen/1170.jpeg
#   inflating: ./Animals/hen/1175.jpeg
#   inflating: ./Animals/hen/1176.jpeg
#   inflating: ./Animals/hen/118.jpeg
#   inflating: ./Animals/hen/1184.jpeg
#   inflating: ./Animals/hen/1188.jpeg
#   inflating: ./Animals/hen/119.jpeg
#   inflating: ./Animals/hen/1196.jpeg
#   inflating: ./Animals/hen/1197.jpeg
#   inflating: ./Animals/hen/1198.jpeg
#   inflating: ./Animals/hen/1199.jpeg
#   inflating: ./Animals/hen/1201.jpeg
#   inflating: ./Animals/hen/1202.jpeg
#   inflating: ./Animals/hen/1207.jpeg
#   inflating: ./Animals/hen/1213.jpeg
#   inflating: ./Animals/hen/1214.jpeg
#   inflating: ./Animals/hen/1215.jpeg
#   inflating: ./Animals/hen/1216.jpeg
#   inflating: ./Animals/hen/1218.jpeg
#   inflating: ./Animals/hen/122.jpeg
#   inflating: ./Animals/hen/1224.jpeg
#   inflating: ./Animals/hen/1225.jpeg
#   inflating: ./Animals/hen/1226.jpeg
#   inflating: ./Animals/hen/1231.jpeg
#   inflating: ./Animals/hen/1233.jpeg
#   inflating: ./Animals/hen/1235.jpeg
#   inflating: ./Animals/hen/1236.jpeg
#   inflating: ./Animals/hen/1239.jpeg
#   inflating: ./Animals/hen/1242.jpeg
#   inflating: ./Animals/hen/1253.jpeg
#   inflating: ./Animals/hen/126.jpeg
#   inflating: ./Animals/hen/127.jpeg
#   inflating: ./Animals/hen/128.jpeg
#   inflating: ./Animals/hen/130.jpeg
#   inflating: ./Animals/hen/134.jpeg
#   inflating: ./Animals/hen/135.jpeg
#   inflating: ./Animals/hen/138.jpeg
#   inflating: ./Animals/hen/139.jpeg
#   inflating: ./Animals/hen/14.jpeg
#   inflating: ./Animals/hen/140.jpeg
#   inflating: ./Animals/hen/142.jpeg
#   inflating: ./Animals/hen/143.jpeg
#   inflating: ./Animals/hen/144.jpeg
#   inflating: ./Animals/hen/145.jpeg
#   inflating: ./Animals/hen/147.jpeg
#   inflating: ./Animals/hen/148.jpeg
#   inflating: ./Animals/hen/153.jpeg
#   inflating: ./Animals/hen/156.jpeg
#   inflating: ./Animals/hen/158.jpeg
#   inflating: ./Animals/hen/16.jpeg
#   inflating: ./Animals/hen/161.jpeg
#   inflating: ./Animals/hen/162.jpeg
#   inflating: ./Animals/hen/163.jpeg
#   inflating: ./Animals/hen/166.jpeg
#   inflating: ./Animals/hen/167.jpeg
#   inflating: ./Animals/hen/168.jpeg
#   inflating: ./Animals/hen/17.jpeg
#   inflating: ./Animals/hen/172.jpeg
#   inflating: ./Animals/hen/174.jpeg
#   inflating: ./Animals/hen/176.jpeg
#   inflating: ./Animals/hen/178.jpeg
#   inflating: ./Animals/hen/180.jpeg
#   inflating: ./Animals/hen/181.jpeg
#   inflating: ./Animals/hen/183.jpeg
#   inflating: ./Animals/hen/185.jpeg
#   inflating: ./Animals/hen/186.jpeg
#   inflating: ./Animals/hen/187.jpeg
#   inflating: ./Animals/hen/188.jpeg
#   inflating: ./Animals/hen/189.jpeg
#   inflating: ./Animals/hen/19.jpeg
#   inflating: ./Animals/hen/190.jpeg
#   inflating: ./Animals/hen/192.jpeg
#   inflating: ./Animals/hen/194.jpeg
#   inflating: ./Animals/hen/198.jpeg
#   inflating: ./Animals/hen/2.jpeg
#   inflating: ./Animals/hen/200.jpeg
#   inflating: ./Animals/hen/204.jpeg
#   inflating: ./Animals/hen/21.jpeg
#   inflating: ./Animals/hen/213.jpeg
#   inflating: ./Animals/hen/214.jpeg
#   inflating: ./Animals/hen/215.jpeg
#   inflating: ./Animals/hen/218.jpeg
#   inflating: ./Animals/hen/221.jpeg
#   inflating: ./Animals/hen/223.jpeg
#   inflating: ./Animals/hen/224.jpeg
#   inflating: ./Animals/hen/226.jpeg
#   inflating: ./Animals/hen/227.jpeg
#   inflating: ./Animals/hen/23.jpeg
#   inflating: ./Animals/hen/230.jpeg
#   inflating: ./Animals/hen/231.jpeg
#   inflating: ./Animals/hen/232.jpeg
#   inflating: ./Animals/hen/233.jpeg
#   inflating: ./Animals/hen/234.jpeg
#   inflating: ./Animals/hen/236.jpeg
#   inflating: ./Animals/hen/237.jpeg
#   inflating: ./Animals/hen/238.jpeg
#   inflating: ./Animals/hen/239.jpeg
#   inflating: ./Animals/hen/240.jpeg
#   inflating: ./Animals/hen/241.jpeg
#   inflating: ./Animals/hen/244.jpeg
#   inflating: ./Animals/hen/247.jpeg
#   inflating: ./Animals/hen/249.jpeg
#   inflating: ./Animals/hen/250.jpeg
#   inflating: ./Animals/hen/251.jpeg
#   inflating: ./Animals/hen/254.jpeg
#   inflating: ./Animals/hen/255.jpeg
#   inflating: ./Animals/hen/256.jpeg
#   inflating: ./Animals/hen/257.jpeg
#   inflating: ./Animals/hen/26.jpeg
#   inflating: ./Animals/hen/262.jpeg
#   inflating: ./Animals/hen/264.jpeg
#   inflating: ./Animals/hen/267.jpeg
#   inflating: ./Animals/hen/27.jpeg
#   inflating: ./Animals/hen/274.jpeg
#   inflating: ./Animals/hen/28.jpeg
#   inflating: ./Animals/hen/284.jpeg
#   inflating: ./Animals/hen/289.jpeg
#   inflating: ./Animals/hen/292.jpeg
#   inflating: ./Animals/hen/296.jpeg
#   inflating: ./Animals/hen/297.jpeg
#   inflating: ./Animals/hen/30.jpeg
#   inflating: ./Animals/hen/303.jpeg
#   inflating: ./Animals/hen/307.jpeg
#   inflating: ./Animals/hen/309.jpeg
#   inflating: ./Animals/hen/31.jpeg
#   inflating: ./Animals/hen/315.jpeg
#   inflating: ./Animals/hen/32.jpeg
#   inflating: ./Animals/hen/323.jpeg
#   inflating: ./Animals/hen/325.jpeg
#   inflating: ./Animals/hen/33.jpeg
#   inflating: ./Animals/hen/335.jpeg
#   inflating: ./Animals/hen/339.jpeg
#   inflating: ./Animals/hen/340.jpeg
#   inflating: ./Animals/hen/341.jpeg
#   inflating: ./Animals/hen/349.jpeg
#   inflating: ./Animals/hen/35.jpeg
#   inflating: ./Animals/hen/350.jpeg
#   inflating: ./Animals/hen/356.jpeg
#   inflating: ./Animals/hen/357.jpeg
#   inflating: ./Animals/hen/358.jpeg
#   inflating: ./Animals/hen/359.jpeg
#   inflating: ./Animals/hen/365.jpeg
#   inflating: ./Animals/hen/368.jpeg
#   inflating: ./Animals/hen/37.jpeg
#   inflating: ./Animals/hen/374.jpeg
#   inflating: ./Animals/hen/376.jpeg
#   inflating: ./Animals/hen/377.jpeg
#   inflating: ./Animals/hen/379.jpeg
#   inflating: ./Animals/hen/380.jpeg
#   inflating: ./Animals/hen/382.jpeg
#   inflating: ./Animals/hen/383.jpeg
#   inflating: ./Animals/hen/386.jpeg
#   inflating: ./Animals/hen/389.jpeg
#   inflating: ./Animals/hen/39.jpeg
#   inflating: ./Animals/hen/390.jpeg
#   inflating: ./Animals/hen/398.jpeg
#   inflating: ./Animals/hen/399.jpeg
#   inflating: ./Animals/hen/4.jpeg
#   inflating: ./Animals/hen/40.jpeg
#   inflating: ./Animals/hen/400.jpeg
#   inflating: ./Animals/hen/401.jpeg
#   inflating: ./Animals/hen/402.jpeg
#   inflating: ./Animals/hen/403.jpeg
#   inflating: ./Animals/hen/405.jpeg
#   inflating: ./Animals/hen/407.jpeg
#   inflating: ./Animals/hen/410.jpeg
#   inflating: ./Animals/hen/414.jpeg
#   inflating: ./Animals/hen/417.jpeg
#   inflating: ./Animals/hen/420.jpeg
#   inflating: ./Animals/hen/421.jpeg
#   inflating: ./Animals/hen/422.jpeg
#   inflating: ./Animals/hen/425.jpeg
#   inflating: ./Animals/hen/428.jpeg
#   inflating: ./Animals/hen/429.jpeg
#   inflating: ./Animals/hen/43.jpeg
#   inflating: ./Animals/hen/430.jpeg
#   inflating: ./Animals/hen/431.jpeg
#   inflating: ./Animals/hen/434.jpeg
#   inflating: ./Animals/hen/437.jpeg
#   inflating: ./Animals/hen/440.jpeg
#   inflating: ./Animals/hen/441.jpeg
#   inflating: ./Animals/hen/443.jpeg
#   inflating: ./Animals/hen/444.jpeg
#   inflating: ./Animals/hen/447.jpeg
#   inflating: ./Animals/hen/448.jpeg
#   inflating: ./Animals/hen/451.jpeg
#   inflating: ./Animals/hen/453.jpeg
#   inflating: ./Animals/hen/454.jpeg
#   inflating: ./Animals/hen/455.jpeg
#   inflating: ./Animals/hen/456.jpeg
#   inflating: ./Animals/hen/460.jpeg
#   inflating: ./Animals/hen/465.jpeg
#   inflating: ./Animals/hen/466.jpeg
#   inflating: ./Animals/hen/467.jpeg
#   inflating: ./Animals/hen/468.jpeg
#   inflating: ./Animals/hen/471.jpeg
#   inflating: ./Animals/hen/476.jpeg
#   inflating: ./Animals/hen/477.jpeg
#   inflating: ./Animals/hen/480.jpeg
#   inflating: ./Animals/hen/481.jpeg
#   inflating: ./Animals/hen/485.jpeg
#   inflating: ./Animals/hen/486.jpeg
#   inflating: ./Animals/hen/487.jpeg
#   inflating: ./Animals/hen/489.jpeg
#   inflating: ./Animals/hen/49.jpeg
#   inflating: ./Animals/hen/490.jpeg
#   inflating: ./Animals/hen/492.jpeg
#   inflating: ./Animals/hen/494.jpeg
#   inflating: ./Animals/hen/498.jpeg
#   inflating: ./Animals/hen/499.jpeg
#   inflating: ./Animals/hen/5.jpeg
#   inflating: ./Animals/hen/50.jpeg
#   inflating: ./Animals/hen/502.jpeg
#   inflating: ./Animals/hen/503.jpeg
#   inflating: ./Animals/hen/504.jpeg
#   inflating: ./Animals/hen/507.jpeg
#   inflating: ./Animals/hen/51.jpeg
#   inflating: ./Animals/hen/511.jpeg
#   inflating: ./Animals/hen/514.jpeg
#   inflating: ./Animals/hen/517.jpeg
#   inflating: ./Animals/hen/521.jpeg
#   inflating: ./Animals/hen/522.jpeg
#   inflating: ./Animals/hen/524.jpeg
#   inflating: ./Animals/hen/525.jpeg
#   inflating: ./Animals/hen/53.jpeg
#   inflating: ./Animals/hen/532.jpeg
#   inflating: ./Animals/hen/533.jpeg
#   inflating: ./Animals/hen/539.jpeg
#   inflating: ./Animals/hen/54.jpeg
#   inflating: ./Animals/hen/540.jpeg
#   inflating: ./Animals/hen/542.jpeg
#   inflating: ./Animals/hen/543.jpeg
#   inflating: ./Animals/hen/544.jpeg
#   inflating: ./Animals/hen/546.jpeg
#   inflating: ./Animals/hen/547.jpeg
#   inflating: ./Animals/hen/550.jpeg
#   inflating: ./Animals/hen/552.jpeg
#   inflating: ./Animals/hen/556.jpeg
#   inflating: ./Animals/hen/557.jpeg
#   inflating: ./Animals/hen/558.jpeg
#   inflating: ./Animals/hen/559.jpeg
#   inflating: ./Animals/hen/560.jpeg
#   inflating: ./Animals/hen/561.jpeg
#   inflating: ./Animals/hen/563.jpeg
#   inflating: ./Animals/hen/565.jpeg
#   inflating: ./Animals/hen/566.jpeg
#   inflating: ./Animals/hen/568.jpeg
#   inflating: ./Animals/hen/569.jpeg
#   inflating: ./Animals/hen/570.jpeg
#   inflating: ./Animals/hen/571.jpeg
#   inflating: ./Animals/hen/572.jpeg
#   inflating: ./Animals/hen/573.jpeg
#   inflating: ./Animals/hen/574.jpeg
#   inflating: ./Animals/hen/575.jpeg
#   inflating: ./Animals/hen/576.jpeg
#   inflating: ./Animals/hen/577.jpeg
#   inflating: ./Animals/hen/578.jpeg
#   inflating: ./Animals/hen/579.jpeg
#   inflating: ./Animals/hen/581.jpeg
#   inflating: ./Animals/hen/582.jpeg
#   inflating: ./Animals/hen/583.jpeg
#   inflating: ./Animals/hen/584.jpeg
#   inflating: ./Animals/hen/586.jpeg
#   inflating: ./Animals/hen/588.jpeg
#   inflating: ./Animals/hen/590.jpeg
#   inflating: ./Animals/hen/591.jpeg
#   inflating: ./Animals/hen/593.jpeg
#   inflating: ./Animals/hen/594.jpeg
#   inflating: ./Animals/hen/595.jpeg
#   inflating: ./Animals/hen/599.jpeg
#   inflating: ./Animals/hen/6.jpeg
#   inflating: ./Animals/hen/60.jpeg
#   inflating: ./Animals/hen/600.jpeg
#   inflating: ./Animals/hen/601.jpeg
#   inflating: ./Animals/hen/602.jpeg
#   inflating: ./Animals/hen/603.jpeg
#   inflating: ./Animals/hen/604.jpeg
#   inflating: ./Animals/hen/605.jpeg
#   inflating: ./Animals/hen/606.jpeg
#   inflating: ./Animals/hen/607.jpeg
#   inflating: ./Animals/hen/609.jpeg
#   inflating: ./Animals/hen/610.jpeg
#   inflating: ./Animals/hen/611.jpeg
#   inflating: ./Animals/hen/613.jpeg
#   inflating: ./Animals/hen/619.jpeg
#   inflating: ./Animals/hen/62.jpeg
#   inflating: ./Animals/hen/628.jpeg
#   inflating: ./Animals/hen/630.jpeg
#   inflating: ./Animals/hen/635.jpeg
#   inflating: ./Animals/hen/637.jpeg
#   inflating: ./Animals/hen/638.jpeg
#   inflating: ./Animals/hen/64.jpeg
#   inflating: ./Animals/hen/641.jpeg
#   inflating: ./Animals/hen/642.jpeg
#   inflating: ./Animals/hen/643.jpeg
#   inflating: ./Animals/hen/648.jpeg
#   inflating: ./Animals/hen/649.jpeg
#   inflating: ./Animals/hen/651.jpeg
#   inflating: ./Animals/hen/655.jpeg
#   inflating: ./Animals/hen/661.jpeg
#   inflating: ./Animals/hen/662.jpeg
#   inflating: ./Animals/hen/664.jpeg
#   inflating: ./Animals/hen/666.jpeg
#   inflating: ./Animals/hen/669.jpeg
#   inflating: ./Animals/hen/670.jpeg
#   inflating: ./Animals/hen/671.jpeg
#   inflating: ./Animals/hen/675.jpeg
#   inflating: ./Animals/hen/677.jpeg
#   inflating: ./Animals/hen/680.jpeg
#   inflating: ./Animals/hen/681.jpeg
#   inflating: ./Animals/hen/682.jpeg
#   inflating: ./Animals/hen/683.jpeg
#   inflating: ./Animals/hen/685.jpeg
#   inflating: ./Animals/hen/687.jpeg
#   inflating: ./Animals/hen/688.jpeg
#   inflating: ./Animals/hen/689.jpeg
#   inflating: ./Animals/hen/690.jpeg
#   inflating: ./Animals/hen/691.jpeg
#   inflating: ./Animals/hen/692.jpeg
#   inflating: ./Animals/hen/695.jpeg
#   inflating: ./Animals/hen/696.jpeg
#   inflating: ./Animals/hen/698.jpeg
#   inflating: ./Animals/hen/699.jpeg
#   inflating: ./Animals/hen/700.jpeg
#   inflating: ./Animals/hen/701.jpeg
#   inflating: ./Animals/hen/702.jpeg
#   inflating: ./Animals/hen/703.jpeg
#   inflating: ./Animals/hen/704.jpeg
#   inflating: ./Animals/hen/705.jpeg
#   inflating: ./Animals/hen/710.jpeg
#   inflating: ./Animals/hen/713.jpeg
#   inflating: ./Animals/hen/714.jpeg
#   inflating: ./Animals/hen/727.jpeg
#   inflating: ./Animals/hen/728.jpeg
#   inflating: ./Animals/hen/737.jpeg
#   inflating: ./Animals/hen/741.jpeg
#   inflating: ./Animals/hen/742.jpeg
#   inflating: ./Animals/hen/746.jpeg
#   inflating: ./Animals/hen/762.jpeg
#   inflating: ./Animals/hen/763.jpeg
#   inflating: ./Animals/hen/764.jpeg
#   inflating: ./Animals/hen/765.jpeg
#   inflating: ./Animals/hen/769.jpeg
#   inflating: ./Animals/hen/771.jpeg
#   inflating: ./Animals/hen/772.jpeg
#   inflating: ./Animals/hen/778.jpeg
#   inflating: ./Animals/hen/781.jpeg
#   inflating: ./Animals/hen/783.jpeg
#   inflating: ./Animals/hen/784.jpeg
#   inflating: ./Animals/hen/785.jpeg
#   inflating: ./Animals/hen/790.jpeg
#   inflating: ./Animals/hen/794.jpeg
#   inflating: ./Animals/hen/796.jpeg
#   inflating: ./Animals/hen/797.jpeg
#   inflating: ./Animals/hen/798.jpeg
#   inflating: ./Animals/hen/800.jpeg
#   inflating: ./Animals/hen/801.jpeg
#   inflating: ./Animals/hen/802.jpeg
#   inflating: ./Animals/hen/804.jpeg
#   inflating: ./Animals/hen/805.jpeg
#   inflating: ./Animals/hen/807.jpeg
#   inflating: ./Animals/hen/808.jpeg
#   inflating: ./Animals/hen/809.jpeg
#   inflating: ./Animals/hen/810.jpeg
#   inflating: ./Animals/hen/813.jpeg
#   inflating: ./Animals/hen/814.jpeg
#   inflating: ./Animals/hen/815.jpeg
#   inflating: ./Animals/hen/816.jpeg
#   inflating: ./Animals/hen/817.jpeg
#   inflating: ./Animals/hen/827.jpeg
#   inflating: ./Animals/hen/830.jpeg
#   inflating: ./Animals/hen/839.jpeg
#   inflating: ./Animals/hen/84.jpeg
#   inflating: ./Animals/hen/843.jpeg
#   inflating: ./Animals/hen/847.jpeg
#   inflating: ./Animals/hen/849.jpeg
#   inflating: ./Animals/hen/855.jpeg
#   inflating: ./Animals/hen/856.jpeg
#   inflating: ./Animals/hen/857.jpeg
#   inflating: ./Animals/hen/859.jpeg
#   inflating: ./Animals/hen/861.jpeg
#   inflating: ./Animals/hen/864.jpeg
#   inflating: ./Animals/hen/867.jpeg
#   inflating: ./Animals/hen/869.jpeg
#   inflating: ./Animals/hen/87.jpeg
#   inflating: ./Animals/hen/870.jpeg
#   inflating: ./Animals/hen/871.jpeg
#   inflating: ./Animals/hen/872.jpeg
#   inflating: ./Animals/hen/873.jpeg
#   inflating: ./Animals/hen/874.jpeg
#   inflating: ./Animals/hen/88.jpeg
#   inflating: ./Animals/hen/880.jpeg
#   inflating: ./Animals/hen/881.jpeg
#   inflating: ./Animals/hen/884.jpeg
#   inflating: ./Animals/hen/885.jpeg
#   inflating: ./Animals/hen/886.jpeg
#   inflating: ./Animals/hen/889.jpeg
#   inflating: ./Animals/hen/89.jpeg
#   inflating: ./Animals/hen/890.jpeg
#   inflating: ./Animals/hen/894.jpeg
#   inflating: ./Animals/hen/895.jpeg
#   inflating: ./Animals/hen/898.jpeg
#   inflating: ./Animals/hen/899.jpeg
#   inflating: ./Animals/hen/9.jpeg
#   inflating: ./Animals/hen/900.jpeg
#   inflating: ./Animals/hen/901.jpeg
#   inflating: ./Animals/hen/903.jpeg
#   inflating: ./Animals/hen/909.jpeg
#   inflating: ./Animals/hen/91.jpeg
#   inflating: ./Animals/hen/910.jpeg
#   inflating: ./Animals/hen/912.jpeg
#   inflating: ./Animals/hen/913.jpeg
#   inflating: ./Animals/hen/915.jpeg
#   inflating: ./Animals/hen/917.jpeg
#   inflating: ./Animals/hen/918.jpeg
#   inflating: ./Animals/hen/92.jpeg
#   inflating: ./Animals/hen/922.jpeg
#   inflating: ./Animals/hen/924.jpeg
#   inflating: ./Animals/hen/925.jpeg
#   inflating: ./Animals/hen/926.jpeg
#   inflating: ./Animals/hen/927.jpeg
#   inflating: ./Animals/hen/928.jpeg
#   inflating: ./Animals/hen/929.jpeg
#   inflating: ./Animals/hen/931.jpeg
#   inflating: ./Animals/hen/932.jpeg
#   inflating: ./Animals/hen/933.jpeg
#   inflating: ./Animals/hen/934.jpeg
#   inflating: ./Animals/hen/935.jpeg
#   inflating: ./Animals/hen/938.jpeg
#   inflating: ./Animals/hen/939.jpeg
#   inflating: ./Animals/hen/940.jpeg
#   inflating: ./Animals/hen/941.jpeg
#   inflating: ./Animals/hen/942.jpeg
#   inflating: ./Animals/hen/943.jpeg
#   inflating: ./Animals/hen/945.jpeg
#   inflating: ./Animals/hen/946.jpeg
#   inflating: ./Animals/hen/947.jpeg
#   inflating: ./Animals/hen/949.jpeg
#   inflating: ./Animals/hen/950.jpeg
#   inflating: ./Animals/hen/951.jpeg
#   inflating: ./Animals/hen/952.jpeg
#   inflating: ./Animals/hen/953.jpeg
#   inflating: ./Animals/hen/954.jpeg
#   inflating: ./Animals/hen/955.jpeg
#   inflating: ./Animals/hen/956.jpeg
#   inflating: ./Animals/hen/957.jpeg
#   inflating: ./Animals/hen/958.jpeg
#   inflating: ./Animals/hen/96.jpeg
#   inflating: ./Animals/hen/961.jpeg
#   inflating: ./Animals/hen/962.jpeg
#   inflating: ./Animals/hen/963.jpeg
#   inflating: ./Animals/hen/964.jpeg
#   inflating: ./Animals/hen/965.jpeg
#   inflating: ./Animals/hen/967.jpeg
#   inflating: ./Animals/hen/968.jpeg
#   inflating: ./Animals/hen/969.jpeg
#   inflating: ./Animals/hen/97.jpeg
#   inflating: ./Animals/hen/972.jpeg
#   inflating: ./Animals/hen/981.jpeg
#   inflating: ./Animals/hen/982.jpeg
#   inflating: ./Animals/hen/984.jpeg
#   inflating: ./Animals/hen/991.jpeg
#   inflating: ./Animals/hen/992.jpeg
#   inflating: ./Animals/hen/994.jpeg
#   inflating: ./Animals/hen/OIP-_0frOH3lwxaRvEhKsGkiogHaFQ.jpeg
#   inflating: ./Animals/hen/OIP-_4ZaNQngcJr0fm-Gp-zHQAHaIn.jpeg
#   inflating: ./Animals/hen/OIP-_7tE6qBa2D6s4YVDwT7TcQHaJ4.jpeg
#   inflating: ./Animals/hen/OIP-_9mwAP9EkNcpd08g6A4XawHaFj.jpeg
#   inflating: ./Animals/hen/OIP-_bfjOKkbF7szNndBXMHeHgHaEF.jpeg
#   inflating: ./Animals/hen/OIP-_btU23OHny7Zl46R9t0qPwHaI5.jpeg
#   inflating: ./Animals/hen/OIP-_EVbG8aIl95u_WOlYf3k-QHaDf.jpeg
#   inflating: ./Animals/hen/OIP-_f3wLgkmBejyFdDbR1WguQHaGi.jpeg
#   inflating: ./Animals/hen/OIP-_fB4cX2rutPB9Q9BBrcCjwHaFj.jpeg
#   inflating: ./Animals/hen/OIP-_FTLVDgIOsVn2WacP5_K5wHaLC.jpeg
#   inflating: ./Animals/hen/OIP-_G562eG_cNMABq-WqPrJWQHaE8.jpeg
#   inflating: ./Animals/hen/OIP-_MeLvbFBblGSSZ2ksKsDNwHaGx.jpeg
#   inflating: ./Animals/hen/OIP-_MSB387XQ7YyLM2G8GISYgHaF_.jpeg
#   inflating: ./Animals/hen/OIP-_Nd6-9eC_Mw4-2dBIU0lRgHaFj.jpeg
#   inflating: ./Animals/hen/OIP-_nmIPiLyLE8tECp6zYFKrwHaGw.jpeg
#   inflating: ./Animals/hen/OIP-_P4KU9ivNmV6rhWEHiZFDwHaE9.jpeg
#   inflating: ./Animals/hen/OIP-_QSU2bYtEyAz4YP9DOED6gHaE7.jpeg
#   inflating: ./Animals/hen/OIP-_-quJDmXrT2nRLANm9PSVAHaFj.jpeg
#   inflating: ./Animals/hen/OIP-_shINE4hcbzelLi0__IkUwHaE8.jpeg
#   inflating: ./Animals/hen/OIP-_SiOSjJ9M2yqyTedf5r3swHaD4.jpeg
#   inflating: ./Animals/hen/OIP-_Sq48sdLU8OKqaJtMj8VZAHaIT.jpeg
#   inflating: ./Animals/hen/OIP-_TI9mZVdCs2yhFUnYZ8k7QHaJ7.jpeg
#   inflating: ./Animals/hen/OIP-_TQiLInlBh8s5iLF5KpD5wHaFj.jpeg
#   inflating: ./Animals/hen/OIP-_txqnK6GtB9nhFPMgRzcVAHaE4.jpeg
#   inflating: ./Animals/hen/OIP-_unfNFDhfHPfDqcx46N1DQHaJ3.jpeg
#   inflating: ./Animals/hen/OIP-_uWzl2a2VbiwVROZiitBOAHaFj.jpeg
#   inflating: ./Animals/hen/OIP-_VBEevMZ5jJn5G2qG6GHVwHaE8.jpeg
#   inflating: ./Animals/hen/OIP-_w0ZU-E6ct5AhsixqvSLfQHaES.jpeg
#   inflating: ./Animals/hen/OIP-_X5DG5EPJjcXGQNwNi874QHaGl.jpeg
#   inflating: ./Animals/hen/OIP-_yR039-4XwAnK2Tz14UJ5AHaLH.jpeg
#   inflating: ./Animals/hen/OIP-_znRphRRmkJHnObfQ5XKLgEsDh.jpeg
#   inflating: ./Animals/hen/OIP-02eikDZOzCE3zTkjL-58WgHaNK.jpeg
#   inflating: ./Animals/hen/OIP-03EvGyDDLnwlOpBhZg-MIgHaHB.jpeg
#   inflating: ./Animals/hen/OIP-07B0eWxoeb7IIWZ3S6IHMwHaIo.jpeg
#   inflating: ./Animals/hen/OIP-07TcG-5GOMsGKgwFw2y_MgHaE8.jpeg
#   inflating: ./Animals/hen/OIP-08_SKBCc-yukohxiA-IQXQHaHa.jpeg
#   inflating: ./Animals/hen/OIP-08IK3U5bFFbSDY6fb4KNFwHaIv.jpeg
#   inflating: ./Animals/hen/OIP-08Mf2rN9-A3v3bzUvUwJ0wHaFj.jpeg
#   inflating: ./Animals/hen/OIP-093MUfXxhLody2lfmXKjIgHaEK.jpeg
#   inflating: ./Animals/hen/OIP-0CW7oMumRtIOjeesB9mMKAHaEw.jpeg
#   inflating: ./Animals/hen/OIP-0eoiefEYzGtdhze72616FgHaGO.jpeg
#   inflating: ./Animals/hen/OIP-0iheyzDkgle3bfQMzic69QHaFj.jpeg
#   inflating: ./Animals/hen/OIP-0iwAxVqsd-MXjowjR-w1cAHaFj.jpeg
#   inflating: ./Animals/hen/OIP-0iZmSc4QUJGzW1XD74jQHQHaFj.jpeg
#   inflating: ./Animals/hen/OIP-0KWGkwrF-HaUoWqTHbc2cQHaFj.jpeg
#   inflating: ./Animals/hen/OIP-0LJkQyVbC2ZBzc87VNjmFAHaFj.jpeg
#   inflating: ./Animals/hen/OIP-0LRl6weII0IU0mriFsViewHaFc.jpeg
#   inflating: ./Animals/hen/OIP-0M2EIEDwEygjzFHrEqMrsAHaE7.jpeg
#   inflating: ./Animals/hen/OIP-0MDhq5_ru-lCoHzv_XUkGAHaHa.jpeg
#   inflating: ./Animals/hen/OIP-0MuLHYUx608laQ2zPIJqHgHaHa.jpeg
#   inflating: ./Animals/hen/OIP-0OX_tpOEE1uVeEbRIfDGwwHaFh.jpeg
#   inflating: ./Animals/hen/OIP-0QsYJP0KKa--ly5WYRWKNQHaFj.jpeg
#   inflating: ./Animals/hen/OIP-0RskGHdgDdmrtCGTNPT_VgHaEK.jpeg
#   inflating: ./Animals/hen/OIP-0URTloG2q6bPq1xGpZYk1gAAAA.jpeg
#   inflating: ./Animals/hen/OIP-0wIOPXoLPpEqnoP3wvLFBwHaGD.jpeg
#   inflating: ./Animals/hen/OIP-0wPPbpqqNHwVOVg8tEzaZQHaEK.jpeg
#   inflating: ./Animals/hen/OIP-0wTugGhp4MsDuNrrIGwEswHaEK.jpeg
#   inflating: ./Animals/hen/OIP-0wZ8uuWxEwwlLKmy_FV0PwHaFj.jpeg
#   inflating: ./Animals/hen/OIP-0xFYEfl78hdV9I586jBTSAHaFj.jpeg
#   inflating: ./Animals/hen/OIP-0xsxdRPMtdWDG_0B1qdCygHaHa.jpeg
#   inflating: ./Animals/hen/OIP-0Yo_rabCFAa2o_J0YzAATAHaFj.jpeg
#   inflating: ./Animals/hen/OIP-0Z55cSMObJsEspfG2vh5GwHaE7.jpeg
#   inflating: ./Animals/hen/OIP-0zhmfjmNI5aTXMtkSrADBAHaLZ.jpeg
#   inflating: ./Animals/hen/OIP-0ZTxJa9cVsKxghH81MCqcgHaE8.jpeg
#   inflating: ./Animals/hen/OIP-0zvsFV69NvXSsgbYj8l6uQHaFj.jpeg
#   inflating: ./Animals/hen/OIP-1_Y1PTa5Pkhwp9L8PMrmCwHaFj.jpeg
#   inflating: ./Animals/hen/OIP-11znjIVHCaoG58HiDUOzIwHaFm.jpeg
#   inflating: ./Animals/hen/OIP-137VwhBjHzzbolhzgPk7uQHaFp.jpeg
#   inflating: ./Animals/hen/OIP-13-m7oEryXRCeEgDOnup-gHaE9.jpeg
#   inflating: ./Animals/hen/OIP-157iq1hi2vMDHqIidR0SMgHaLG.jpeg
#   inflating: ./Animals/hen/OIP-15FXhhL_Y6L0HloC9_8XNgHaHa.jpeg
#   inflating: ./Animals/hen/OIP-15nRmlLrTJ5msdj_P--o6wHaFj.jpeg
#   inflating: ./Animals/hen/OIP-15O0oTR_rhOmv7ALngZKOwHaG-.jpeg
#   inflating: ./Animals/hen/OIP-15Oizj-HvNZRzfY3gy3uUgHaFj.jpeg
#   inflating: ./Animals/hen/OIP-15SDX3sCGjAu87g1SIG2TAHaNK.jpeg
#   inflating: ./Animals/hen/OIP-17-lGSVXlvBXO_oYZzkY9QHaFi.jpeg
#   inflating: ./Animals/hen/OIP-18beOJJDSU-sR1SNDedPigHaJ4.jpeg
#   inflating: ./Animals/hen/OIP-1b6kV5YOZGH7NLnjNFIPZAHaGl.jpeg
#   inflating: ./Animals/hen/OIP-1-BDQEvxRYXeOKIFtqi1ogHaDh.jpeg
#   inflating: ./Animals/hen/OIP-1Bja_nb4NQlGEwu6lIa-5AHaFj.jpeg
#   inflating: ./Animals/hen/OIP-1EFiBG38s_tkFx2xpyrMuAHaFk.jpeg
#   inflating: ./Animals/hen/OIP-1eurQbzoAUhZgeWBCzwspQHaFV.jpeg
#   inflating: ./Animals/hen/OIP-1fH_MozrwAqmAhvL6rUXWAHaFj.jpeg
#   inflating: ./Animals/hen/OIP-1G1SP9tcet9a0MdZfp-A5wHaHa.jpeg
#   inflating: ./Animals/hen/OIP-1HrP30Id-qDKKO7rmNshzQHaE8.jpeg
#   inflating: ./Animals/hen/OIP-1HX0aErjDbd4mGmDSS4McQHaHL.jpeg
#   inflating: ./Animals/hen/OIP-1iWmWeHWOyxWsrB0Pvf1dAHaFj.jpeg
#   inflating: ./Animals/hen/OIP-1j_jAvfvY9LAX-JXQXvVZQHaF3.jpeg
#   inflating: ./Animals/hen/OIP-1lN9lwdHGP2VrJ3ffT7KggHaFj.jpeg
#   inflating: ./Animals/hen/OIP-1MGbFP8cKQojqED14P2oEQAAAA.jpeg
#   inflating: ./Animals/hen/OIP-1nFJY00dzPeXBIgAZ7UwHQHaHa.jpeg
#   inflating: ./Animals/hen/OIP-1PP_G9o3_pHuwi-KpHzhbQHaE8.jpeg
#   inflating: ./Animals/hen/OIP-1QlzIUYu2i6b9wK8MqfOtQHaGT.jpeg
#   inflating: ./Animals/hen/OIP-1Qs70Jqa6zrHbWQYPRUhEAHaHa.jpeg
#   inflating: ./Animals/hen/OIP-1RgbRTqQgZyTBXkjIJve6AAAAA.jpeg
#   inflating: ./Animals/hen/OIP-1s9rxxS4Yed7JjSjQV-qywHaGP.jpeg
#   inflating: ./Animals/hen/OIP-1SQib5zts4yhdHiwdiXrEQHaFj.jpeg
#   inflating: ./Animals/hen/OIP-1SqM1TE2gs6KEp5yQPw_bgHaGy.jpeg
#   inflating: ./Animals/hen/OIP-1TpqofQVnnF6dVAm1wHCtQHaFj.jpeg
#   inflating: ./Animals/hen/OIP-1uNnTf649Y6QQb0ixvuoAAHaEJ.jpeg
#   inflating: ./Animals/hen/OIP-1wY8PtZKE9MfktKX7vegIgHaHa.jpeg
#   inflating: ./Animals/hen/OIP-1X4rSGknlbamEqoF0xHBFQHaFj.jpeg
#   inflating: ./Animals/hen/OIP-1z1sRkLnG5Csiq7yNhUn5gHaFz.jpeg
#   inflating: ./Animals/hen/OIP-1zHoGzG2DuTuR0btWfS8igHaE8.jpeg
#   inflating: ./Animals/hen/OIP-248Ye-VcMD5gDgd1lX20yAHaFj.jpeg
#   inflating: ./Animals/hen/OIP-24Vuyh1h2DtiJ6XqoHZVzQHaJ4.jpeg
#   inflating: ./Animals/hen/OIP-25amo-GlCzN_OU_V0XLNzgHaF8.jpeg
#   inflating: ./Animals/hen/OIP-29NUbm3oNyrrUo3dcL0WJgHaJb.jpeg
#   inflating: ./Animals/hen/OIP-2AW-Ey2pmwe-sVfbVAiXZAHaHa.jpeg
#   inflating: ./Animals/hen/OIP-2c7ROqFRnvlwkCz6yuv6XAHaFj.jpeg
#   inflating: ./Animals/hen/OIP-2cqlUfhKMre4d3anNXGJ3wHaEK.jpeg
#   inflating: ./Animals/hen/OIP-2CysOvCCiGpYktDJq7dsUAAAAA.jpeg
#   inflating: ./Animals/hen/OIP-2DJyMQtPudbkH28pc1PCowHaG7.jpeg
#   inflating: ./Animals/hen/OIP-2EP4-hEy5iFzhf2uLLMGvQHaE8.jpeg
#   inflating: ./Animals/hen/OIP-2EpNl0p3BgEqPA1-yL2ZIQHaD4.jpeg
#   inflating: ./Animals/hen/OIP--2gNU3N3KyfAV4yIoCAj1wHaE7.jpeg
#   inflating: ./Animals/hen/OIP-2gpfEOEIetBWtosIFyXYTwHaGa.jpeg
#   inflating: ./Animals/hen/OIP-2GQJ61GPqJsOUg69-H9dgwHaFj.jpeg
#   inflating: ./Animals/hen/OIP-2h8auSr1bwht5ta592PmLQHaFP.jpeg
#   inflating: ./Animals/hen/OIP-2HjGXr8hsCdkbUvRuNtgKgHaNK.jpeg
#   inflating: ./Animals/hen/OIP-2j7XZHENYUjFQqWMmpGQmwHaFj.jpeg
#   inflating: ./Animals/hen/OIP-2jhd41ltLiujoMaq33XwPwHaHa.jpeg
#   inflating: ./Animals/hen/OIP-2jlbrU52vKF21v2ASCjHTgHaFj.jpeg
#   inflating: ./Animals/hen/OIP-2kEbd6RQhWShlc-iqedKtAHaFj.jpeg
#   inflating: ./Animals/hen/OIP--2l1RBZrwbcEta73nYEu6gHaGs.jpeg
#   inflating: ./Animals/hen/OIP-2lc7tpFI404OqX9xhR7-XwHaHY.jpeg
#   inflating: ./Animals/hen/OIP-2MgCoXLnISUM5YgWhZ-YTAHaE8.jpeg
#   inflating: ./Animals/hen/OIP-2mmmW-CslXEcush0zDYrJQHaIL.jpeg
#   inflating: ./Animals/hen/OIP-2nbjhBG_cB-U-T2eSs94pwHaHa.jpeg
#   inflating: ./Animals/hen/OIP-2o1JeTlIo4uVws6EyM25VwHaFj.jpeg
#   inflating: ./Animals/hen/OIP-2OpfHGe1C8vzQtomMrBrVAHaHa.jpeg
#   inflating: ./Animals/hen/OIP-2PsBAARaQY8yrfE2oK37DAHaE8.jpeg
#   inflating: ./Animals/hen/OIP-2PshZmHVWIHQ4kd0tQn7bwHaKK.jpeg
#   inflating: ./Animals/hen/OIP-2qdsOtllzmb4EEvxqLLHrwHaKu.jpeg
#   inflating: ./Animals/hen/OIP-2qfqwXTn_3NCnRQy0usrcgHaHY.jpeg
#   inflating: ./Animals/hen/OIP-2QWoo_Jj2H5bExE4iUKqQQHaFw.jpeg
#   inflating: ./Animals/hen/OIP-2Sv3e0Lfc_29imA3Zye0qwHaE_.jpeg
#   inflating: ./Animals/hen/OIP-2T2Diusj24nm1vBoKmHVhgHaHn.jpeg
#   inflating: ./Animals/hen/OIP-2TU0YKKIKGM-oQ-3m0fItwHaFj.jpeg
#   inflating: ./Animals/hen/OIP-2-UK2DyeeNUtYuyH1lMJnAHaFL.jpeg
#   inflating: ./Animals/hen/OIP-2U-rJLQ7buJi7sfnjNZl7QHaFj.jpeg
#   inflating: ./Animals/hen/OIP--2UWWMFtiau-M70B_RTU3AHaFj.jpeg
#   inflating: ./Animals/hen/OIP-2vJVf6lOOavv8vWXiqA8qQHaGp.jpeg
#   inflating: ./Animals/hen/OIP-2wAhEoChHIuVqo6PsPGi3wHaFb.jpeg
#   inflating: ./Animals/hen/OIP-2wnVq-Ixoj_sN-LedIOpowHaIX.jpeg
#   inflating: ./Animals/hen/OIP-2x1a0T4CZ_vJLx0wkFSNIgHaEj.jpeg
#   inflating: ./Animals/hen/OIP-2Xtx-sLEKhEmdmHjteE55QAAAA.jpeg
#   inflating: ./Animals/hen/OIP-2ytHpJPr6hU1kuRCHZ1IZwHaHa.jpeg
#   inflating: ./Animals/hen/OIP-2ywR9AepqtOD-JHXzBm_dAHaFj.jpeg
#   inflating: ./Animals/hen/OIP-2zubZT6pNB2K_SxSPQfQ-QHaHa.jpeg
#   inflating: ./Animals/hen/OIP-316x-9yl0lLRgSwQJsFaxwHaJA.jpeg
#   inflating: ./Animals/hen/OIP-31DhipvrGOmryqw2Dj5IoAHaFj.jpeg
#   inflating: ./Animals/hen/OIP-35z7vK1gtUgdFAcvcvEOPQHaFj.jpeg
#   inflating: ./Animals/hen/OIP-368k-BqXdBhP-4aZ6tGHTwDnEs.jpeg
#   inflating: ./Animals/hen/OIP-36elQbqGo67KzSUE6W-5OQHaHW.jpeg
#   inflating: ./Animals/hen/OIP-36KNbTlfdvhxLRAJFd8JLwHaE7.jpeg
#   inflating: ./Animals/hen/OIP-38Tn9VSTNRN8-TZnMvl1sAHaFj.jpeg
#   inflating: ./Animals/hen/OIP-3amMffZ3ebbHLQMfeilcGwHaFj.jpeg
#   inflating: ./Animals/hen/OIP-3bj_2vuG9xX77fz_7LZkvgHaEK.jpeg
#   inflating: ./Animals/hen/OIP-3C0nKePl9Pm-VqHKea5vYAAAAA.jpeg
#   inflating: ./Animals/hen/OIP-3CBtSNNEoYsa2l4vNtWRQAHaFj.jpeg
#   inflating: ./Animals/hen/OIP-3CRxJoaPCc4lUgemJumC8AAAAA.jpeg
#   inflating: ./Animals/hen/OIP-3cuIRCNcZeNAX0taeS8vLAHaE8.jpeg
#   inflating: ./Animals/hen/OIP-3DBdn6mVGQzn_vczh1FoAAHaHR.jpeg
#   inflating: ./Animals/hen/OIP-3DbkXNZfduFS_rGJb2GXIwHaFj.jpeg
#   inflating: ./Animals/hen/OIP-3eSG4CXAf8ivfnXRtWSH3gHaEK.jpeg
#   inflating: ./Animals/hen/OIP-3f_3f6shE0JGBHfaRck23AHaFj.jpeg
#   inflating: ./Animals/hen/OIP-3fBTdzBLZplnFJriKIF-QwHaFj.jpeg
#   inflating: ./Animals/hen/OIP-3GSeR9BuGXptqIvSgFt0QgHaHa.jpeg
#   inflating: ./Animals/hen/OIP-3gSfe4O3T38uzLLJMA_GmQHaE7.jpeg
#   inflating: ./Animals/hen/OIP-3gxM5-MSg2nsK7SnCLRjAQHaFj.jpeg
#   inflating: ./Animals/hen/OIP-3hV0wCjmF8SU6YYhdboAfAHaE8.jpeg
#   inflating: ./Animals/hen/OIP-3KG5T5FdUlAbTk5GgzCR_wHaE7.jpeg
#   inflating: ./Animals/hen/OIP-3kWhfq0W5g2wtWvDSvy8QwHaFj.jpeg
#   inflating: ./Animals/hen/OIP-3n3lP6d4gSvLREoeibv6vwHaFh.jpeg
#   inflating: ./Animals/hen/OIP-3NaFDc8p3X0kW_eMf8bk6gHaE8.jpeg
#   inflating: ./Animals/hen/OIP-3O1Z6y84vXTPO_k0bSp74gHaJ9.jpeg
#   inflating: ./Animals/hen/OIP-3oBZXLJvPUvO3d_fo86LaAHaIK.jpeg
#   inflating: ./Animals/hen/OIP-3ocQGpNzHnXC5YaevlJejAHaG6.jpeg
#   inflating: ./Animals/hen/OIP-3oE1lS5vNfisajRqa96hswHaFy.jpeg
#   inflating: ./Animals/hen/OIP-3oU-U6cTxYcxgk9HuT_y2AHaJp.jpeg
#   inflating: ./Animals/hen/OIP-3Ppm8Tt2cyTZAw9zouby3QHaFj.jpeg
#   inflating: ./Animals/hen/OIP-3Pri9Ihq2sLSNKWj_1eENwDiET.jpeg
#   inflating: ./Animals/hen/OIP-3ra_N-3ZFwBnbtMJWZQkzAAAAA.jpeg
#   inflating: ./Animals/hen/OIP-3RJbvJfScb064oTqMinUFAHaHa.jpeg
#   inflating: ./Animals/hen/OIP-3RjiqcDJZALLujMunM85eQHaFj.jpeg
#   inflating: ./Animals/hen/OIP-3Td6nv4o9vV9lNkDqcFstQHaJ0.jpeg
#   inflating: ./Animals/hen/OIP-3TFavZsG6nOxhp__iHs27QHaGu.jpeg
#   inflating: ./Animals/hen/OIP-3TTsEaFYAflAGo_QNK6skQHaFK.jpeg
#   inflating: ./Animals/hen/OIP-3UlCDkh4anG-Z_CNyreu4gHaKf.jpeg
#   inflating: ./Animals/hen/OIP-3VbNxrpYtvpir_eD7pwKGQHaHa.jpeg
#   inflating: ./Animals/hen/OIP-3VZIW6grsBUsnc2Gp710vAHaFj.jpeg
#   inflating: ./Animals/hen/OIP-3YdviNHgl4aL_HaLZwtgUQEsDh.jpeg
#   inflating: ./Animals/hen/OIP-3yFAN9TUzizwpb4VcHcX1QHaIV.jpeg
#   inflating: ./Animals/hen/OIP-3Yn3AfDgocTd4gbKgiXFhwHaEK.jpeg
#   inflating: ./Animals/hen/OIP-3zX6mdfRz1GySomzMj7q0wHaE6.jpeg
#   inflating: ./Animals/hen/OIP--40awT_93UdCdX2oSBQK7AHaE7.jpeg
#   inflating: ./Animals/hen/OIP-41RZ-KLH76oHww2fOIfCfgHaF7.jpeg
#   inflating: ./Animals/hen/OIP-42hG55ep120uLw0AZ7zybwHaHa.jpeg
#   inflating: ./Animals/hen/OIP-42OMs1eamj9kgtHYh3IQPAAAAA.jpeg
#   inflating: ./Animals/hen/OIP-431qqphfHQZNiKI086mR5QHaG6.jpeg
#   inflating: ./Animals/hen/OIP-453GOlsjBjpCWNUBhUBKWAHaFj.jpeg
#   inflating: ./Animals/hen/OIP-4a2rC0lndrBZZIKBuWl0eAEsDE.jpeg
#   inflating: ./Animals/hen/OIP-4ai0RBALpsAxgyRko2sUwAHaGZ.jpeg
#   inflating: ./Animals/hen/OIP-4AKJ7AnYtPiWkfNQ8lh8gAFNC7.jpeg
#   inflating: ./Animals/hen/OIP-4B9ujmBjFBM2Ft8jIpxSYwHaFj.jpeg
#   inflating: ./Animals/hen/OIP-4BG4GBcsd5RKVmVPY-KeKwHaFj.jpeg
#   inflating: ./Animals/hen/OIP-4BjfBK_9WgxmyKbDmbNKLgHaFa.jpeg
#   inflating: ./Animals/hen/OIP-4bSPw0m56vq0820q0Ld3vQHaEK.jpeg
#   inflating: ./Animals/hen/OIP-4c0AouRTDwlh2okBsbewXAHaEL.jpeg
#   inflating: ./Animals/hen/OIP-4CiYbaukRDr29EYbvR_iZQHaE7.jpeg
#   inflating: ./Animals/hen/OIP-4fH89j9tchcUKs2dTh0xwwHaGk.jpeg
#   inflating: ./Animals/hen/OIP-4FWLzelNXAguO01LN-DZ2wHaFj.jpeg
#   inflating: ./Animals/hen/OIP-4if2Gwp5F3ZsFaeF9ZnF8QEsDh.jpeg
#   inflating: ./Animals/hen/OIP-4ikCv9t_vD-ccR8lA2cftAAAAA.jpeg
#   inflating: ./Animals/hen/OIP-4Iogz6K290RKMhaSxPkLCwAAAA.jpeg
#   inflating: ./Animals/hen/OIP-4IwFsPGxsQAmJz8fy_2M4gHaEK.jpeg
#   inflating: ./Animals/hen/OIP-4K6u64FXI0N51ZUtKg2_ewHaDk.jpeg
#   inflating: ./Animals/hen/OIP-4KH-Mzc3w5Y9467FCe7NQgHaFj.jpeg
#   inflating: ./Animals/hen/OIP-4LiAVjhQSs9qawNVEuXbFQAAAA.jpeg
#   inflating: ./Animals/hen/OIP-4Ll5Plw8pRKXAaJLgslGSAHaEc.jpeg
#   inflating: ./Animals/hen/OIP-4Mj7p0GAtD_YS_h5wAwfGQHaE4.jpeg
#   inflating: ./Animals/hen/OIP-4NkpNmbki98Rl0Cas7DSLwHaFj.jpeg
#   inflating: ./Animals/hen/OIP-4nnFJLYedhOKU8sPTaVypQHaHa.jpeg
#   inflating: ./Animals/hen/OIP-4OLPW12yupivB9eLMvR5HAHaHO.jpeg
#   inflating: ./Animals/hen/OIP-4ovqN-DFebpVa0aMlUVN0QHaFj.jpeg
#   inflating: ./Animals/hen/OIP-4PNwewHRWmwbwbmN686RlQHaDa.jpeg
#   inflating: ./Animals/hen/OIP-4-ptxqHKnAu9a5LfYuhwPwHaFj.jpeg
#   inflating: ./Animals/hen/OIP-4QiGnEkXZTar_sPj7sRcDAHaEK.jpeg
#   inflating: ./Animals/hen/OIP-4rq0snwNt-zHi0iIwd4VGwHaFj.jpeg
#   inflating: ./Animals/hen/OIP-4SENUGcJ2yYAhrK2lr2tEgHaE8.jpeg
#   inflating: ./Animals/hen/OIP-4sJqxZv06X3at8238pmeowHaDr.jpeg
#   inflating: ./Animals/hen/OIP-4vb4bRqnsD6j1fr9F13VpAHaEK.jpeg
#   inflating: ./Animals/hen/OIP-4wfNDghUIAdLmVpwLpJRCgHaFj.jpeg
#   inflating: ./Animals/hen/OIP-4w-ODk3_r1OkLZV3diLnXQHaJ4.jpeg
#   inflating: ./Animals/hen/OIP-4WsEp_1DdiE3aHAypi9WIwDMEw.jpeg
#   inflating: ./Animals/hen/OIP-4X7tIjqxr-P7N8T1FgKguwHaFj.jpeg
#   inflating: ./Animals/hen/OIP-4ZOxdRcj8sgkY6a-glq5TgHaFp.jpeg
#   inflating: ./Animals/hen/OIP-50DJ49xaYiWWcoKe5PhDtwHaFj.jpeg
#   inflating: ./Animals/hen/OIP-50vmhkNIM1LKU3JoYIRmegHaFj.jpeg
#   inflating: ./Animals/hen/OIP-51vWgXsO7U54Jibh6uyCDAHaFj.jpeg
#   inflating: ./Animals/hen/OIP-53S5RGbPiznSz5GONZQE9QHaId.jpeg
#   inflating: ./Animals/hen/OIP-54RRj9gpb5GdUxaRxlge0QHaFj.jpeg
#   inflating: ./Animals/hen/OIP-55J4CT1nEh3tMehZkQmqLwHaFj.jpeg
#   inflating: ./Animals/hen/OIP-5aBF2uxc4UEVRCVX4En06AHaE8.jpeg
#   inflating: ./Animals/hen/OIP-5BcxRsI_ZKQaGr_MZKk6JgHaFj.jpeg
#   inflating: ./Animals/hen/OIP-5bKZ-ISESefbZvViZaHlZwHaFc.jpeg
#   inflating: ./Animals/hen/OIP-5dA5IDNJ4vnXuWjKViKVQQHaFj.jpeg
#   inflating: ./Animals/hen/OIP-5dsgQu2hmOGVxtBLZ8mMcwHaEK.jpeg
#   inflating: ./Animals/hen/OIP-5E5MzLuLzSr3rA8nIPGRdQHaHq.jpeg
#   inflating: ./Animals/hen/OIP-5-ENE1iabrqYfA6ksIvh6QHaHa.jpeg
#   inflating: ./Animals/hen/OIP-5fkO5scz765qfsDw7K_qUwHaFj.jpeg
#   inflating: ./Animals/hen/OIP-5fV-r-lSGleyBu82ExeuOgHaFj.jpeg
#   inflating: ./Animals/hen/OIP--5g5OnUD2_qUsPoC9zJpXwHaFk.jpeg
#   inflating: ./Animals/hen/OIP-5hi78fz8pNBaurlInmumqgHaE8.jpeg
#   inflating: ./Animals/hen/OIP-5J6vzmXJO4Xd1CrW94ommgHaG5.jpeg
#   inflating: ./Animals/hen/OIP-5Kee-rXaplUDvaoe_pZV6gHaFi.jpeg
#   inflating: ./Animals/hen/OIP-5L1_hLwThlZ4L1SRAW_cGQAAAA.jpeg
#   inflating: ./Animals/hen/OIP-5muAueNfvBwEc6UfvzfrVQHaJZ.jpeg
#   inflating: ./Animals/hen/OIP-5poiIVmVCZS-3lch6rRXJQHaHa.jpeg
#   inflating: ./Animals/hen/OIP-5qODKS-pxpv16GMFXm8unQEgDY.jpeg
#   inflating: ./Animals/hen/OIP-5QQxtfk3m1yOqyilJY6p7gHaHm.jpeg
#   inflating: ./Animals/hen/OIP-5rfFnNbU8dmSbbt2ru-_QgHaH0.jpeg
#   inflating: ./Animals/hen/OIP-5rK1zqoABl4meZIFhAQ-tAHaFj.jpeg
#   inflating: ./Animals/hen/OIP-5SsgWdXnt6-4LuDNUoG7YQHaEK.jpeg
#   inflating: ./Animals/hen/OIP-5t2n3S3Jcw0Our79ebFK9QHaFj.jpeg
#   inflating: ./Animals/hen/OIP-5VC2vNYI4eSmU8wa0hXfyAAAAA.jpeg
#   inflating: ./Animals/hen/OIP-5WSRINSHm-mR5UtC_6KAbQHaGN.jpeg
#   inflating: ./Animals/hen/OIP-5xdj6OZDMquHsj44EB7nLgHaLG.jpeg
#   inflating: ./Animals/hen/OIP-6_3-_zzEAdELjrFVORvo1AHaJ4.jpeg
#   inflating: ./Animals/hen/OIP-6_cAAImnpahaVzbl19UGCQHaFi.jpeg
#   inflating: ./Animals/hen/OIP-627sqZhpzNQ2Q8xoVWwkcwHaEK.jpeg
#   inflating: ./Animals/hen/OIP-6-3rwlPli37qt7X442m_ZQHaGn.jpeg
#   inflating: ./Animals/hen/OIP-63Tko1ej3YCzWBDIT-uIigHaFj.jpeg
#   inflating: ./Animals/hen/OIP-63VAvmrbTpdfPHmUNmlyZwHaH6.jpeg
#   inflating: ./Animals/hen/OIP-64ZhIxv2ZsMIeZv2kXA2zwAAAA.jpeg
#   inflating: ./Animals/hen/OIP-650WVO_kHeUJxkt9QCZx2AHaE8.jpeg
#   inflating: ./Animals/hen/OIP-67CcjgZaLkCofVRHLf1SwgHaE7.jpeg
#   inflating: ./Animals/hen/OIP-68dQXNDJwQamZI--0_4KegHaEK.jpeg
#   inflating: ./Animals/hen/OIP-6ANGrzFkmgA0OgiJnkDloQHaIt.jpeg
#   inflating: ./Animals/hen/OIP-6ARLobSe9RVQx2WGAQI8qQHaFy.jpeg
#   inflating: ./Animals/hen/OIP-6B59Ynuuopo0dXwo5Jl_TwHaEa.jpeg
#   inflating: ./Animals/hen/OIP-6bSnzf9ggxKb1sDoTybe3gHaFW.jpeg
#   inflating: ./Animals/hen/OIP-6C5L5Jh7z-dBXB3156mwXQHaHp.jpeg
#   inflating: ./Animals/hen/OIP-6Cg9X4caml8KFweKPZIMVQHaEK.jpeg
#   inflating: ./Animals/hen/OIP-6D79QzEVX0_93CEnCyE7PgHaFj.jpeg
#   inflating: ./Animals/hen/OIP-6dzg9pEiFCPxwHwFnJG8VQHaF6.jpeg
#   inflating: ./Animals/hen/OIP-6eDD1go8C_uyIMRXo9NszgAAAA.jpeg
#   inflating: ./Animals/hen/OIP-6fUqiPkC11fCKEJ5lO0AQwHaFj.jpeg
#   inflating: ./Animals/hen/OIP-6G2u0rJVU0i5ZxFebLIqBAHaGG.jpeg
#   inflating: ./Animals/hen/OIP-6g4xUAGE6dwWW0tLiPNQNgHaFj.jpeg
#   inflating: ./Animals/hen/OIP--6HKrfzgEaczswvhprOlnAHaHJ.jpeg
#   inflating: ./Animals/hen/OIP-6i3VIQkka46USNK0eK0LvAAAAA.jpeg
#   inflating: ./Animals/hen/OIP-6I6ayNrn8peLd2ARs4pQMwHaFA.jpeg
#   inflating: ./Animals/hen/OIP-6LP5pfpTQVkNZj4EundaMAHaJ4.jpeg
#   inflating: ./Animals/hen/OIP-6lUE548MW-yMHf2SEkXP7AHaIB.jpeg
#   inflating: ./Animals/hen/OIP-6m7K8FS-eC-B24Z8gbVvRAHaJ6.jpeg
#   inflating: ./Animals/hen/OIP-6mq1IP9zqQUkQ0ypsJmgcQHaFj.jpeg
#   inflating: ./Animals/hen/OIP-6OB2MxAclQ57rheFLrtcYQHaGa.jpeg
#   inflating: ./Animals/hen/OIP-6oDJu446jOOXi7r0oSkqxwHaD6.jpeg
#   inflating: ./Animals/hen/OIP-6ohC-3M5tJPyG_mSrLABQQHaFj.jpeg
#   inflating: ./Animals/hen/OIP-6om1hYGHqnq3Vg3s8waZWwHaGu.jpeg
#   inflating: ./Animals/hen/OIP-6P0oKrob9isGDvjNPay4CwHaJ4.jpeg
#   inflating: ./Animals/hen/OIP-6p96UYNXs-AdpmYX23EGtQHaFj.jpeg
#   inflating: ./Animals/hen/OIP-6pBuOXpTJjTSrE0rwAlbmgHaHa.jpeg
#   inflating: ./Animals/hen/OIP-6pRAdEW6opejwE_8U3dtrQHaFj.jpeg
#   inflating: ./Animals/hen/OIP-6QEYmPbMqTn_g0VFYu4tqAHaFj.jpeg
#   inflating: ./Animals/hen/OIP-6qj20Ql725RUMi5VqwDaXwHaHo.jpeg
#   inflating: ./Animals/hen/OIP-6rFNwZGW6pxztXrOS_soNAFHC-.jpeg
#   inflating: ./Animals/hen/OIP-6S0q7VFLiRLS8SL6mVr7hAHaJU.jpeg
#   inflating: ./Animals/hen/OIP-6skKHMpPJtOq78sxIC0rnwHaE8.jpeg
#   inflating: ./Animals/hen/OIP-6VbP32AjNy478YA6IBr2qQHaF_.jpeg
#   inflating: ./Animals/hen/OIP-6VcqSyzDQ2RoKZM9BD-4kAHaFj.jpeg
#   inflating: ./Animals/hen/OIP-6w6uJIAkSD6xZomMux29iAAAAA.jpeg
#   inflating: ./Animals/hen/OIP-6XunDt9KSsdX_27hqbbg-QHaFj.jpeg
#   inflating: ./Animals/hen/OIP-6zeUQ7xO-gH42XQlSheFMQHaGO.jpeg
#   inflating: ./Animals/hen/OIP-6ZtjxMbaEM5aAh6C_otsWwHaGk.jpeg
#   inflating: ./Animals/hen/OIP-7_cQuxK0H5hEKAvZt_SisAHaEK.jpeg
#   inflating: ./Animals/hen/OIP-702ozZTVHELvS2bLwo-KFgHaFj.jpeg
#   inflating: ./Animals/hen/OIP-71BAd5MwIzkf466Cqmc2pgHaHd.jpeg
#   inflating: ./Animals/hen/OIP-74oZnJVocO5hChrDNv6xiAHaFv.jpeg
#   inflating: ./Animals/hen/OIP-74vG_FDFmHzVRxuBlgKrvQHaFK.jpeg
#   inflating: ./Animals/hen/OIP-75K-4y1cVG52BpcnuYpoxwHaJ4.jpeg
#   inflating: ./Animals/hen/OIP-75sJrJyQsMaBY4YItWW_AgHaE-.jpeg
#   inflating: ./Animals/hen/OIP-77RM92DiwEUqyqWM4rGlUgHaHa.jpeg
#   inflating: ./Animals/hen/OIP-78_Ti31ahXDU9-WSge7RwwHaFj.jpeg
#   inflating: ./Animals/hen/OIP-78I-MaEPyU-Gtw73zMeLUwHaFj.jpeg
#   inflating: ./Animals/hen/OIP-7A__YpPKCyhfnk-Z9OP2uQHaFi.jpeg
#   inflating: ./Animals/hen/OIP-7AAA8RrQ6K-fEhG8TRSBpwHaFj.jpeg
#   inflating: ./Animals/hen/OIP-7AXwJWNtNME5wqk0CpbZigHaE7.jpeg
#   inflating: ./Animals/hen/OIP-7cL3MRF2Ck_F5QiunlVZLgHaFc.jpeg
#   inflating: ./Animals/hen/OIP-7CsMfknKrq78Okr8CubWzAHaE8.jpeg
#   inflating: ./Animals/hen/OIP-7Es8P_OjyihqAwzcTBW0ZgHaFj.jpeg
#   inflating: ./Animals/hen/OIP-7EtWsDZuF4louIcykg_QeAHaFj.jpeg
#   inflating: ./Animals/hen/OIP-7h5ThIQhAh8_qYaeZno93wHaFj.jpeg
#   inflating: ./Animals/hen/OIP-7hWtsOaICkVNVrMNczvUPwHaFj.jpeg
#   inflating: ./Animals/hen/OIP-7Hy2cuHJ6Y4gWw6I4_-0yQHaFj.jpeg
#   inflating: ./Animals/hen/OIP-7I2XmkP_XvIqnYdsqsYulQHaI1.jpeg
#   inflating: ./Animals/hen/OIP-7jdZbEz6mXRRbUoby-ANGAHaFD.jpeg
#   inflating: ./Animals/hen/OIP-7J--lOOQomnyEDyyh_QAYwHaHf.jpeg
#   inflating: ./Animals/hen/OIP-7jSSTwc0sh-F6ZdIFnLdtwHaFj.jpeg
#   inflating: ./Animals/hen/OIP-7KBMGgiHAkaZSkroCJ3kDwAAAA.jpeg
#   inflating: ./Animals/hen/OIP-7Ly9W9Pgfhm59IMX0DfD2AHaGe.jpeg
#   inflating: ./Animals/hen/OIP-7M4pRiZ4ZTzZ1bJ8P_TkVAHaHi.jpeg
#   inflating: ./Animals/hen/OIP-7mfkhF5dOuWxrXtxpah02AEsCo.jpeg
#   inflating: ./Animals/hen/OIP-7OullDOengOsOwV17Gb78AHaH_.jpeg
#   inflating: ./Animals/hen/OIP-7PQ7NzKqmhY1ZcZT3vjeTgHaFj.jpeg
#   inflating: ./Animals/hen/OIP-7S43IWCa-Gp1gHkMIKsCrwHaGP.jpeg
#   inflating: ./Animals/hen/OIP-7S5OKeMiFdy7hiwKouOXTwHaFj.jpeg
#   inflating: ./Animals/hen/OIP-7u_n4O_rhHEXUzyAOTo2swHaJP.jpeg
#   inflating: ./Animals/hen/OIP-7VoezBBUR7WeX2Cx32T8UwHaHa.jpeg
#   inflating: ./Animals/hen/OIP-7WmtyDAsrVPcrNtyo0YFwAAAAA.jpeg
#   inflating: ./Animals/hen/OIP-7WuLpvAlCBquytvSC_fOcwEKEs.jpeg
#   inflating: ./Animals/hen/OIP-7ZgZDVp9HBR6jtH-jl0NhwHaFB.jpeg
#   inflating: ./Animals/hen/OIP-7zp6NfReXD50AydLG6j0VwHaFj.jpeg
#   inflating: ./Animals/hen/OIP-7ZUE1_8TnH2xGhUODx1VkQHaJG.jpeg
#   inflating: ./Animals/hen/OIP-80JmuJ1TPXIBgv-HPaoE3AHaFj.jpeg
#   inflating: ./Animals/hen/OIP-80yUEkbZNPpK_lng8xAJmQHaFj.jpeg
#   inflating: ./Animals/hen/OIP-81E4jNWV0NSu8Aehps2TXgAAAA.jpeg
#   inflating: ./Animals/hen/OIP-8-1tsGyFn5ESzDYvPfjBUAHaGJ.jpeg
#   inflating: ./Animals/hen/OIP-85KnilxdXHdtyOUx-ikP1AHaEK.jpeg
#   inflating: ./Animals/hen/OIP-85TFiYqyfhiigJxj7PZP7wHaGh.jpeg
#   inflating: ./Animals/hen/OIP-8BS0qXkfbkyQLsQiZ04QAwHaFj.jpeg
#   inflating: ./Animals/hen/OIP-8CYTQuhmq0kl3nWwTptdCQHaEK.jpeg
#   inflating: ./Animals/hen/OIP-8d2PCjNtx6dG-9jlt_meiQHaEc.jpeg
#   inflating: ./Animals/hen/OIP-8D4LIFQse5P23Y58c3kKMQEsEs.jpeg
#   inflating: ./Animals/hen/OIP-8d6H5k4ef_X149RFW4nNmgHaEc.jpeg
#   inflating: ./Animals/hen/OIP-8d-BSQQxxmWkNIW7anD_bAHaFj.jpeg
#   inflating: ./Animals/hen/OIP-8ebfhhKJFO3AVi-CqjtYegAAAA.jpeg
#   inflating: ./Animals/hen/OIP-8EEP8nbPWf_k1fR_5gdTYgHaEK.jpeg
#   inflating: ./Animals/hen/OIP-8EU_EcL6_WPdg4H-MB863wHaKg.jpeg
#   inflating: ./Animals/hen/OIP-8H9mhyvRoZwn7SupNkNRswHaHq.jpeg
#   inflating: ./Animals/hen/OIP-8IL-IAkJ59DG8yzBZCEcAgHaFj.jpeg
#   inflating: ./Animals/hen/OIP-8IVGG91ofj4zTmVLlID-bAHaF1.jpeg
#   inflating: ./Animals/hen/OIP-8izNfyQWLo4PfaELbucNWQHaFj.jpeg
#   inflating: ./Animals/hen/OIP-8JZ9RUUAy1lVcCKc7P1SyAHaE6.jpeg
#   inflating: ./Animals/hen/OIP-8K6sUpcL9WSbnl8KlV0aDwHaFj.jpeg
#   inflating: ./Animals/hen/OIP-8L3_V0eYFoWdQ0H1lIpUCAHaFj.jpeg
#   inflating: ./Animals/hen/OIP-8LENM2t2uISaOnTxIqJEqgHaEK.jpeg
#   inflating: ./Animals/hen/OIP-8M9QtrIk2OCzN7J8-IRk-gHaEK.jpeg
#   inflating: ./Animals/hen/OIP-8n-fvDeoPq1HZ6AHNLgC4wHaH0.jpeg
#   inflating: ./Animals/hen/OIP-8NRGVa0Exfs9MiqUjEEQ-QHaFj.jpeg
#   inflating: ./Animals/hen/OIP-8PTXN0qTY1W4ZTJuW9JZSQHaEZ.jpeg
#   inflating: ./Animals/hen/OIP-8qLYp3jlorQgN3LtvhL6zwHaFj.jpeg
#   inflating: ./Animals/hen/OIP-8r-l0kdhJeDeWaNTcBqsmQHaKe.jpeg
#   inflating: ./Animals/hen/OIP-8spT7jPDWS7sR7qaXsZzbgHaGl.jpeg
#   inflating: ./Animals/hen/OIP-8Ss8AZETDgyhczkCYltXYQHaD4.jpeg
#   inflating: ./Animals/hen/OIP-8SsnCihvhYnUwPZls4J8TwHaFj.jpeg
#   inflating: ./Animals/hen/OIP-8TERD5bDQ8wQloNTdnr-cwHaHa.jpeg
#   inflating: ./Animals/hen/OIP-8UIUzwFIopzNLY_pP76iWQHaEK.jpeg
#   inflating: ./Animals/hen/OIP--8UYtBETwRzYg3sYiJqJeAAAAA.jpeg
#   inflating: ./Animals/hen/OIP-8WAkCGwuKi0XbxkMzry7wgHaGW.jpeg
#   inflating: ./Animals/hen/OIP-8wccTIK_idAPtwUirqAb5QHaHg.jpeg
#   inflating: ./Animals/hen/OIP-8WeaRmFex3GzN0LdQciOBgHaEc.jpeg
#   inflating: ./Animals/hen/OIP-8WI5eq75tPkAYD7wv_Ge6wHaHa.jpeg
#   inflating: ./Animals/hen/OIP-8XgdiyoXKHCIiHEjesuI3gHaGU.jpeg
#   inflating: ./Animals/hen/OIP-8xKfc3nI13OWshPUA_4OAgAAAA.jpeg
#   inflating: ./Animals/hen/OIP-8XYnv28bnJuXo76_cPbtbwHaGQ.jpeg
#   inflating: ./Animals/hen/OIP-8yYcfF9p0f7xlm4cHmcrawAAAA.jpeg
#   inflating: ./Animals/hen/OIP-8yyKjZ7mfST7-ngicuc9aAHaIw.jpeg
#   inflating: ./Animals/hen/OIP-8zqg3UfXZdhp8Sej85BSwAHaFj.jpeg
#   inflating: ./Animals/hen/OIP-8zwMUIBZj9UNQ-r4AzabwQHaE8.jpeg
#   inflating: ./Animals/hen/OIP-909Zls7tqtswmiiAxH6PbAAAAA.jpeg
#   inflating: ./Animals/hen/OIP-92MqYQVcRC4GMKfoeEy6mwAAAA.jpeg
#   inflating: ./Animals/hen/OIP-93ZdgDE_h_SoeFcQmTU9rgHaFg.jpeg
#   inflating: ./Animals/hen/OIP-96FKOb0Eqt0TEIuaY3rFUgHaFj.jpeg
#   inflating: ./Animals/hen/OIP-98Xg_w30AAIJ-FQrbj8ZZwAAAA.jpeg
#   inflating: ./Animals/hen/OIP-9-96TsYs8FVnfnEh5YJLCwHaFk.jpeg
#   inflating: ./Animals/hen/OIP-9A_1bHNgDEBL9knlRe0ncQHaFj.jpeg
#   inflating: ./Animals/hen/OIP-9ACDKdF8PHFRu3vjXt39JwHaFj.jpeg
#   inflating: ./Animals/hen/OIP-9AYksAnfB3WyiQ6LyxM1dAHaE7.jpeg
#   inflating: ./Animals/hen/OIP-9bhKxxeyz8Y_0b1HLyazbwHaFj.jpeg
# ...
#   inflating: ./Animals/cow/OIP-O7R-mUv4ne-bXBYLms6tAQHaKA.jpeg
#   inflating: ./Animals/cow/OIP-o7Z4EMnOOHUiKjrD1vSIHgHaEL.jpeg
#   inflating: ./Animals/cow/OIP-o82B5g7-w6OY8Nf5rPFm4QHaFj.jpeg
#   inflating: ./Animals/cow/OIP-O8FRLqDGCWrkfXhSmXj-qgHaFo.jpeg
#   inflating: ./Animals/cow/OIP-O8MEDDkATMHnD845LexNlAHaFJ.jpeg
#   inflating: ./Animals/cow/OIP-O9_ykliT6QXiPaUgvL7COwAAAA.jpeg
#   inflating: ./Animals/cow/OIP-o9Ry28rzOnfO3URVYQ7VZAHaEo.jpeg
#   inflating: ./Animals/cow/OIP-oa0oDx9o-mSLUGOIoQFrUwHaJd.jpeg
#   inflating: ./Animals/cow/OIP-Oa4JAA3-cOi3rWX5I0nb-wHaGf.jpeg
#   inflating: ./Animals/cow/OIP--oaMcE_WNhA-HDJiF4CvNAHaFF.jpeg
#   inflating: ./Animals/cow/OIP-OBsIG-n7qXPDBaqihB5McgHaFk.jpeg
#   inflating: ./Animals/cow/OIP-OBUuXWv6mqOEZaiY6i2i5gHaFV.jpeg
#   inflating: ./Animals/cow/OIP-octqy8aOmeqMUldeqQk4pgHaE5.jpeg
#   inflating: ./Animals/cow/OIP-OEB458bRqYGJD2onv30AJAHaE7.jpeg
#   inflating: ./Animals/cow/OIP-OEb45J8lOaGzCjBwr_h8WQHaE6.jpeg
#   inflating: ./Animals/cow/OIP-of1QCN0wBRcIfC1f8LIHswHaHa.jpeg
#   inflating: ./Animals/cow/OIP-ofl7dyRCRyCFhd1aOQERBAHaFj.jpeg
#   inflating: ./Animals/cow/OIP-OFUDwtAy8x5kussyJ4AYhAHaFZ.jpeg
#   inflating: ./Animals/cow/OIP-oGwJcZNhikLliXSK3uXQ6gHaFU.jpeg
#   inflating: ./Animals/cow/OIP-ohA3CWiD50_xxseojpj7QQHaFO.jpeg
#   inflating: ./Animals/cow/OIP--OHe3g7Mp_Gkr7nCer7fpAHaEy.jpeg
#   inflating: ./Animals/cow/OIP-OhUXqwezMaZ2erOM82TWDgHaFl.jpeg
#   inflating: ./Animals/cow/OIP-o-IvD5q-sleaEZRbxtgAswAAAA.jpeg
#   inflating: ./Animals/cow/OIP--ojaB8xSPBPAxcGSMxrToQHaF7.jpeg
#   inflating: ./Animals/cow/OIP-OkhbgyklzkTGwioFETJgkwHaE1.jpeg
#   inflating: ./Animals/cow/OIP-olx7odZgrOxtGxhhyzkkigHaD1.jpeg
#   inflating: ./Animals/cow/OIP-oMbRtciQ6_Z8h8uE0_9ErAHaFj.jpeg
#   inflating: ./Animals/cow/OIP-oMD72T1nmlaZ4_P6YZqnhwHaLH.jpeg
#   inflating: ./Animals/cow/OIP-OMKBcIGY7h9TJoTdoOC9LwHaJt.jpeg
#   inflating: ./Animals/cow/OIP-omw6K28elR_APsq3CtgPbgHaKF.jpeg
#   inflating: ./Animals/cow/OIP-on7G8qFNpE1cvAHq4xB40gHaEs.jpeg
#   inflating: ./Animals/cow/OIP-oNVJf_VR2Pp5XeEs5d2J5AHaE6.jpeg
#   inflating: ./Animals/cow/OIP-oolgmQt4gXy9NBksS-86DAHaFj.jpeg
#   inflating: ./Animals/cow/OIP-Oq9yCRR529zPeCzmrxKIxwHaE7.jpeg
#   inflating: ./Animals/cow/OIP-OQwgCLM4GGACpJwrYDkQRAHaE8.jpeg
#   inflating: ./Animals/cow/OIP-OR0H8BIXHCgLUL-tVe7d1QHaF8.jpeg
#   inflating: ./Animals/cow/OIP-orCRUX1Cc4WcGCM26v4sLAHaE9.jpeg
#   inflating: ./Animals/cow/OIP-oRHfri5MGeriQgd27KYgCgHaE6.jpeg
#   inflating: ./Animals/cow/OIP-orM9qRL557THKMmPkW2P9gHaFj.jpeg
#   inflating: ./Animals/cow/OIP-ORmYlvHr2lfM8Ah7fZFpPAHaFc.jpeg
#   inflating: ./Animals/cow/OIP-OSgujYLjbpFUemX6jwDKtAHaFV.jpeg
#   inflating: ./Animals/cow/OIP-osN5iKZzhkmbumy0XNDzRAHaLH.jpeg
#   inflating: ./Animals/cow/OIP-Ot0lxm8xFqdN4kQ6tm99pQHaFS.jpeg
#   inflating: ./Animals/cow/OIP-OTDWcSmWgzpZ9M1pBh40nQHaFc.jpeg
#   inflating: ./Animals/cow/OIP-OTWZnNVqR7oCw_X3pgyYkQHaKB.jpeg
#   inflating: ./Animals/cow/OIP-OvpU3KyV3CeGemy3FWt4_AHaGz.jpeg
#   inflating: ./Animals/cow/OIP-oWTuP9VC_qp-ooAC6icv2gHaDu.jpeg
#   inflating: ./Animals/cow/OIP-oWvzxaqK7V5sZGic6MQz3gHaE6.jpeg
#   inflating: ./Animals/cow/OIP-OXdSJsBqNm8yIwAGN8L-4AAAAA.jpeg
#   inflating: ./Animals/cow/OIP-oxxs3OLOowACIabfsmvtlgHaE8.jpeg
#   inflating: ./Animals/cow/OIP-oyfR7soj1kMseayp1k-jXQHaGF.jpeg
#   inflating: ./Animals/cow/OIP-oyou5uGR9eklPqlbbybckwHaFi.jpeg
#   inflating: ./Animals/cow/OIP-OYSl6ioWRMxp1K9EuOFlvAHaLG.jpeg
#   inflating: ./Animals/cow/OIP-ozHNch6cvvdRY3UECPTukgHaFj.jpeg
#   inflating: ./Animals/cow/OIP-OZzF65OpLXB1oF1Tou9uWgHaFj.jpeg
#   inflating: ./Animals/cow/OIP-P_AKIXujbL-uogEenf2ekgHaJ5.jpeg
#   inflating: ./Animals/cow/OIP-P16UW6I0r6KyD0Ir5Z8meAHaE5.jpeg
#   inflating: ./Animals/cow/OIP-p1hVFCpH_Ju9taNdxBIWvAHaE7.jpeg
#   inflating: ./Animals/cow/OIP-p2jtNjNXGEeJ8gvF4XMzRAHaE7.jpeg
#   inflating: ./Animals/cow/OIP-p2LOGFUjRJIA2wpSA4lNaAHaEU.jpeg
#   inflating: ./Animals/cow/OIP-P2tv0XM_koL73268qeIhMgHaE8.jpeg
#   inflating: ./Animals/cow/OIP-P2yEc_CSXvHULCpJFX3uYAHaEz.jpeg
#   inflating: ./Animals/cow/OIP-P3v7GsfK2QClUQswwi7y8AHaEK.jpeg
#   inflating: ./Animals/cow/OIP-p4ifyEpq_1CNleQ0xQ9oNgHaHa.jpeg
#   inflating: ./Animals/cow/OIP-P4McdKZIgL_1We05J8ZezwHaEf.jpeg
#   inflating: ./Animals/cow/OIP--p7-OAxH-TX37sifk38s-gAAAA.jpeg
#   inflating: ./Animals/cow/OIP-pbOrf3-ajjPFchdhFSownwHaFj.jpeg
#   inflating: ./Animals/cow/OIP-pBpo_9uRCpeTXcpDT2ZNwAHaLI.jpeg
#   inflating: ./Animals/cow/OIP-PCf00eCTpYW8a2tIL6gn_AHaE7.jpeg
#   inflating: ./Animals/cow/OIP-PeeuSClF_VzqsLzLkg2wMgHaFD.jpeg
#   inflating: ./Animals/cow/OIP-Ph_9hjr2SN2na5MA9ZmGuAHaE7.jpeg
#   inflating: ./Animals/cow/OIP-Ph1azwIZRdJQL7rWMiGXtgHaFS.jpeg
#   inflating: ./Animals/cow/OIP-PhBY66HsuYRFnmwFQTsOqQHaFc.jpeg
#   inflating: ./Animals/cow/OIP-PhjNyP91ieR0SmoUMNQ00AHaDf.jpeg
#   inflating: ./Animals/cow/OIP-phMe9Rf_r3RVwGcg2RHpVwHaFj.jpeg
#   inflating: ./Animals/cow/OIP-pHSwjkjxLR1lFTVAu98UjwHaE7.jpeg
#   inflating: ./Animals/cow/OIP-piG__9vXwHJpnn-RA_8LeQHaE6.jpeg
#   inflating: ./Animals/cow/OIP-pJ8LUJyzccdD224yIr5gBwHaFj.jpeg
#   inflating: ./Animals/cow/OIP-P-jGO9PUemMfQKUOpNmNVwHaE7.jpeg
#   inflating: ./Animals/cow/OIP-PJWEwIw8wxaktjg4fgxmmAHaFP.jpeg
#   inflating: ./Animals/cow/OIP-pl69wPPCYQq5Yo9tDHUtQQAAAA.jpeg
#   inflating: ./Animals/cow/OIP-plxzuABYk3Dl_0gi96y4LwHaFj.jpeg
#   inflating: ./Animals/cow/OIP--pMZNATl-k0LT3yHuKVfwAAAAA.jpeg
#   inflating: ./Animals/cow/OIP-PN7gYP4zWadXMyPciNpUOgAAAA.jpeg
#   inflating: ./Animals/cow/OIP-PNgtX7Tjh38ED73_6SenmAHaFj.jpeg
#   inflating: ./Animals/cow/OIP-Pq2cLPPiUiI1zOpLUh0lbwHaEK.jpeg
#   inflating: ./Animals/cow/OIP-pqJflNmwoYOCBiXHuzEusgHaFj.jpeg
#   inflating: ./Animals/cow/OIP-pR0ZNk54KL87fCL6UDQHjAHaEa.jpeg
#   inflating: ./Animals/cow/OIP-PrC8phy4M1vnV_G42zni8QHaFJ.jpeg
#   inflating: ./Animals/cow/OIP-PrQc3Nz9r04N4FO1uOjBaAHaE5.jpeg
#   inflating: ./Animals/cow/OIP-PsD2MyrUV-dI2fA6bJ-VeQHaFb.jpeg
#   inflating: ./Animals/cow/OIP-P-SD3cR7KuMdZTHmyLErlwHaFj.jpeg
#   inflating: ./Animals/cow/OIP-psjzupvk_wkeZYiW6okGDwHaFa.jpeg
#   inflating: ./Animals/cow/OIP-pSQHfssGpF6o5-yVIN35FwHaFc.jpeg
#   inflating: ./Animals/cow/OIP-PsyerNB2JD_Y4keuymFTigHaFj.jpeg
#   inflating: ./Animals/cow/OIP-ptl22fwweQPJyHuXNMXolgAAAA.jpeg
#   inflating: ./Animals/cow/OIP-pTVji5PY3bRwdZ0YQq9wpAHaE7.jpeg
#   inflating: ./Animals/cow/OIP-PUB35rMctZcdjw38ad_VxQHaD4.jpeg
#   inflating: ./Animals/cow/OIP-PVEwg9nT6cT-u2SFaLlw3AHaE8.jpeg
#   inflating: ./Animals/cow/OIP-PVI_gUzVUkywkCJFqUzNrwHaGF.jpeg
#   inflating: ./Animals/cow/OIP-Pw_MMo00PW4sMFcN4wAPegHaE-.jpeg
#   inflating: ./Animals/cow/OIP-PWLEgMfM3cFBSbNl6_P3IQHaFf.jpeg
#   inflating: ./Animals/cow/OIP-pX51bdFyO3OPPqu3BDbX2wAAAA.jpeg
#   inflating: ./Animals/cow/OIP-Pxhft4VDDCkyU0kmo6mygwAAAA.jpeg
#   inflating: ./Animals/cow/OIP-pyeDHvhqi8LQmS3a3qCX3gHaGC.jpeg
#   inflating: ./Animals/cow/OIP-PZPDkI5PUhvvDbvLrwcIuwHaE_.jpeg
#   inflating: ./Animals/cow/OIP-PZqXQU7k0H9IGVeBte4yjgHaFj.jpeg
#   inflating: ./Animals/cow/OIP-q0yy9LhcB4T3rB0cNWv7IQHaEJ.jpeg
#   inflating: ./Animals/cow/OIP-q46zS0r0nvLKwfzy6h2nVQHaE8.jpeg
#   inflating: ./Animals/cow/OIP-q49SaHO878hGu6_3breJMQHaFb.jpeg
#   inflating: ./Animals/cow/OIP-q4u4ivZ3cT8LNwQz_hX0JgHaJ3.jpeg
#   inflating: ./Animals/cow/OIP-Q5ElrO-RTtSHM6Q4HhENrgHaE8.jpeg
#   inflating: ./Animals/cow/OIP-QAS8A2iLozPuEMdkQViYHwHaE7.jpeg
#   inflating: ./Animals/cow/OIP-QavRk_mtjk2lz0AB3E8VlAHaHa.jpeg
#   inflating: ./Animals/cow/OIP-QB1CfqXX-Vn1paaWHJ7TeAHaFp.jpeg
#   inflating: ./Animals/cow/OIP-QCiTY2HsVvh0icPM_CQYXAHaFj.jpeg
#   inflating: ./Animals/cow/OIP-QczXGzuET6Mumpe0sQ6F4AHaE8.jpeg
#   inflating: ./Animals/cow/OIP-qEJOfpbpEoLsTew57PB8RQHaE7.jpeg
#   inflating: ./Animals/cow/OIP-Qemchz5U9CHkoCVQRN9DfwHaFj.jpeg
#   inflating: ./Animals/cow/OIP-Qeu64WnbEzCudkWUaR8OoAAAAA.jpeg
#   inflating: ./Animals/cow/OIP-qf6IYOcu7zifbFhED9n4VAHaEK.jpeg
#   inflating: ./Animals/cow/OIP-qFAO3JnVwNquxoqRpP7R1AHaFU.jpeg
#   inflating: ./Animals/cow/OIP-qFJ2LEQPxq4_uSoibEvk0AHaD_.jpeg
#   inflating: ./Animals/cow/OIP-QFuJ86ruXeTmTMeOfKd1EgHaFj.jpeg
#   inflating: ./Animals/cow/OIP-qFZdWyL94E-2UiUVQIpbcwHaLJ.jpeg
#   inflating: ./Animals/cow/OIP-QgKwZeaF0t9Azj9v6_WFAwHaFG.jpeg
#   inflating: ./Animals/cow/OIP-qGuyYzG52QpEgd2KrUZDswHaEy.jpeg
#   inflating: ./Animals/cow/OIP-qijT67pKZkWvimaHT0054wHaFb.jpeg
#   inflating: ./Animals/cow/OIP-qiNRG6Txg1-yAB2VZQwHPAHaEZ.jpeg
#   inflating: ./Animals/cow/OIP-qkdjcFHMl4v5NJMUHPisGAHaFd.jpeg
#   inflating: ./Animals/cow/OIP-QKk-s8Z9if0RLVxwYp9l8AHaE8.jpeg
#   inflating: ./Animals/cow/OIP-qKP99GUPYdDjJEpRIaIp_gHaKD.jpeg
#   inflating: ./Animals/cow/OIP-QkqKdWlO-Fo2T2k23eLOoAHaFN.jpeg
#   inflating: ./Animals/cow/OIP-qKRfIz4z6lOaebXN29qqqwHaE8.jpeg
#   inflating: ./Animals/cow/OIP-qLBNGfpzrMUSFzu1-YXrpQHaH4.jpeg
#   inflating: ./Animals/cow/OIP-QLNLjaCL0tdJJ4UfzjOEEwHaFj.jpeg
#   inflating: ./Animals/cow/OIP-QluQD01gbss266ut7FcjPwHaE8.jpeg
#   inflating: ./Animals/cow/OIP-QlZNweyWoDQ3L3sg0o6n9AHaE8.jpeg
#   inflating: ./Animals/cow/OIP-qMK2wZz018jsuttRk547dAHaFj.jpeg
#   inflating: ./Animals/cow/OIP-Qms-pUyu5mCx0vB9G19fBgHaHa.jpeg
#   inflating: ./Animals/cow/OIP-QnVvhLas-d8SEERDK6ZlXgHaE7.jpeg
#   inflating: ./Animals/cow/OIP-QNXg7dEwjiqm8onAO7S9TwHaFj.jpeg
#   inflating: ./Animals/cow/OIP-qoSPuFAfFxZrsxhpJZu2swHaES.jpeg
#   inflating: ./Animals/cow/OIP-qpf99NRm4RiPDXjYuIz2tAEeDa.jpeg
#   inflating: ./Animals/cow/OIP-qPrQYAE_yXwHeLhdK3IE1QAAAA.jpeg
#   inflating: ./Animals/cow/OIP-QQcInjMRSwDzd1ve-CxK5AHaFN.jpeg
#   inflating: ./Animals/cow/OIP-QrfmJ8qoHLFHLtm-hFjlDwHaE7.jpeg
#   inflating: ./Animals/cow/OIP-qSSi-QP7gifcyXriXIfZYQHaE4.jpeg
#   inflating: ./Animals/cow/OIP-QTpj9ebqCeR0G7XnWhCb_wHaE8.jpeg
#   inflating: ./Animals/cow/OIP-QU80RlOzW4QL0dtb4_WH3QHaHa.jpeg
#   inflating: ./Animals/cow/OIP-QUsz1G1YcAh6CrGIYLAqcAHaE5.jpeg
#   inflating: ./Animals/cow/OIP-QuUQXInmQVQRpdssei9RMgHaE_.jpeg
#   inflating: ./Animals/cow/OIP-QWrJbhjYRr-J407tD2ACUgHaEL.jpeg
#   inflating: ./Animals/cow/OIP-QX_bXghaCz9BAMI1WrtvEQHaEI.jpeg
#   inflating: ./Animals/cow/OIP-QxE2Qwy5E-NYUQU8fw-43gAAAA.jpeg
#   inflating: ./Animals/cow/OIP-qXE9oa3T4vru9-1DYkllWwHaFm.jpeg
#   inflating: ./Animals/cow/OIP-qXtpo4P4qOwF2OHw-3j4HAHaIn.jpeg
#   inflating: ./Animals/cow/OIP-qy0ylZfqUu1mRaKjhw-WFQHaE7.jpeg
#   inflating: ./Animals/cow/OIP-Qy620GCqLQ1_mM9kG4qD_AHaE6.jpeg
#   inflating: ./Animals/cow/OIP-Qy9whRZBA4jgu_fSMhrv8wHaE4.jpeg
#   inflating: ./Animals/cow/OIP-QyrFh1Xq06G7ZK6ETn6PigHaFj.jpeg
#   inflating: ./Animals/cow/OIP-QYtYBt08eQNfCKokoxx1OAHaE7.jpeg
#   inflating: ./Animals/cow/OIP--QZbYG1Khwn66kljNYFGTgHaFl.jpeg
#   inflating: ./Animals/cow/OIP-qzmRrh4iWYRJAwnZnf-28wHaFi.jpeg
#   inflating: ./Animals/cow/OIP-r0OQlvx5yEIUZr0DuDJYugHaEK.jpeg
#   inflating: ./Animals/cow/OIP-r2cOlYqMl0hUjqENb8XMBgHaFK.jpeg
#   inflating: ./Animals/cow/OIP-r2dqXi1OTUQt8Mtbib3CrgHaFo.jpeg
#   inflating: ./Animals/cow/OIP-r-2xWu8jyZY8s8rJpbcUOgHaE7.jpeg
#   inflating: ./Animals/cow/OIP-r38Qxb70f3kZ0KH8-UqnogHaFW.jpeg
#   inflating: ./Animals/cow/OIP-R41kFUehSNnocpd7v4RWIgHaF0.jpeg
#   inflating: ./Animals/cow/OIP-r5-0XSPpwcmgYfX2-2-1igHaE5.jpeg
#   inflating: ./Animals/cow/OIP-r5p1ZeN4LEt_trVS1FX8owHaE7.jpeg
#   inflating: ./Animals/cow/OIP-R6Z8NR21HZn-4sHYa1cnqAHaHM.jpeg
#   inflating: ./Animals/cow/OIP-r7YsRNHaOkEEH39LWFNUZwHaFj.jpeg
#   inflating: ./Animals/cow/OIP-r86kmgRrTQ64DoBAUlQHLgHaFj.jpeg
#   inflating: ./Animals/cow/OIP-RAgGJJf42cHg0DXIC5BV3QHaFj.jpeg
#   inflating: ./Animals/cow/OIP-rBPZSHwmhJaRuNtdS-oqxQHaJs.jpeg
#   inflating: ./Animals/cow/OIP-RDyQhVpWbcCG08G9rxQ0aQHaFh.jpeg
#   inflating: ./Animals/cow/OIP-rENBsR8WqrsVYR4lrmA-UgHaFj.jpeg
#   inflating: ./Animals/cow/OIP-rEnPTRH-mAHCoWt51GZWhwHaE9.jpeg
#   inflating: ./Animals/cow/OIP-RfjzUSlYTqjzs1Agcl1ZJgHaFj.jpeg
#   inflating: ./Animals/cow/OIP-rfM2HwCM-pcl4uzori3L_AHaFR.jpeg
#   inflating: ./Animals/cow/OIP-RGh9iiN6CubW4YL-GoGy8wHaEm.jpeg
#   inflating: ./Animals/cow/OIP-rgRVFP3__h-n_E6YHhVUhwAAAA.jpeg
#   inflating: ./Animals/cow/OIP-rhwLL2_PmwZ1VLsGduQGngAAAA.jpeg
#   inflating: ./Animals/cow/OIP-RHyD-revccAwnXKBsuiXYwHaE8.jpeg
#   inflating: ./Animals/cow/OIP-rIU3C78skMQXHB0eznSZUgHaE7.jpeg
#   inflating: ./Animals/cow/OIP-rj747r5ezVf4kvYD324CLgAAAA.jpeg
#   inflating: ./Animals/cow/OIP-rKxpte2TZpvUDiB18t8iLwHaEc.jpeg
#   inflating: ./Animals/cow/OIP-RkzHrmDSWB6saJnL45gRpgHaFA.jpeg
#   inflating: ./Animals/cow/OIP-rLmXVnErpAn3aeQGjECe4QHaFk.jpeg
#   inflating: ./Animals/cow/OIP-r-LsgWeUlpAZNgMjNP1xXQHaF7.jpeg
#   inflating: ./Animals/cow/OIP-RN5dAS8EqMZmDjQJ0I6XyQHaD9.jpeg
#   inflating: ./Animals/cow/OIP-RoXUKZZ7uPzWprXfU5qA3gHaE8.jpeg
#   inflating: ./Animals/cow/OIP-R-p_gH1NLRrJiHS5eBG0DQAAAA.jpeg
#   inflating: ./Animals/cow/OIP-rp3lhaiomNstxHUCj1PKbwHaE7.jpeg
#   inflating: ./Animals/cow/OIP-Rq407olNFcPIjAzXu2cDHAHaFV.jpeg
#   inflating: ./Animals/cow/OIP-rqhUo-oFrV_IJTFQJZQxSQHaFj.jpeg
#   inflating: ./Animals/cow/OIP-rqZWTD1cAb5wHeAluHYg_QHaF7.jpeg
#   inflating: ./Animals/cow/OIP-RRn7M4sRzlRCJv3IH1V0oAHaFj.jpeg
#   inflating: ./Animals/cow/OIP-RT6no221m8wWxeJPgBhv2QHaFL.jpeg
#   inflating: ./Animals/cow/OIP-RtJf9wufOKF0iCNcg60E5QHaE7.jpeg
#   inflating: ./Animals/cow/OIP-RTPZQue2HtimZfLLAQsZzAHaEE.jpeg
#   inflating: ./Animals/cow/OIP-rucHdaKcXRmOard82tOt6QHaEt.jpeg
#   inflating: ./Animals/cow/OIP-rum7ixc-w4rE7WrhK-aLSQHaE0.jpeg
#   inflating: ./Animals/cow/OIP-rVhsW5NLbDPjAKriCxoT0AHaD5.jpeg
#   inflating: ./Animals/cow/OIP-Rwtjr_sb7rU8nOofXsSYdwHaE7.jpeg
#   inflating: ./Animals/cow/OIP-rwzMyOZbQEHYnEciAFxkigHaFT.jpeg
#   inflating: ./Animals/cow/OIP-RyyIWpQeJQA_zxXayXq0jAHaD1.jpeg
#   inflating: ./Animals/cow/OIP-RzBw5UlYLPGaO3okcB5wcwHaFj.jpeg
#   inflating: ./Animals/cow/OIP-RZIEJFYOw9MLeOAYd1oYoAHaFS.jpeg
#   inflating: ./Animals/cow/OIP-rZiTssC8y9El07-EszIiiwHaFa.jpeg
#   inflating: ./Animals/cow/OIP-RzQ9mBIjmfO8T96iiwSb0AHaE8.jpeg
#   inflating: ./Animals/cow/OIP-RZQfcA39i4x_XBb6-yNz1AHaE-.jpeg
#   inflating: ./Animals/cow/OIP-s_1QtM8VhSaqM-FfONzAWwHaFS.jpeg
#   inflating: ./Animals/cow/OIP-S0g1PbhR180IevY9Nre9xgHaFj.jpeg
#   inflating: ./Animals/cow/OIP-s3iTEPHFNsI55tENpS0iKAHaE8.jpeg
#   inflating: ./Animals/cow/OIP-S4hoJJgDZb3wJxzQ7S76oQHaEv.jpeg
#   inflating: ./Animals/cow/OIP-S5MqPN8adBG7eIPq7atthAHaE9.jpeg
#   inflating: ./Animals/cow/OIP-s5tn7PL9tUKyYG1ltunTXAHaD6.jpeg
#   inflating: ./Animals/cow/OIP-s9M0JpNeOthXLVAeADgpzQHaCH.jpeg
#   inflating: ./Animals/cow/OIP-scUxsLkPEWNEXDpb0MKXjQHaE8.jpeg
#   inflating: ./Animals/cow/OIP-SCYXDX-MwszAniHiCDL48QHaFj.jpeg
#   inflating: ./Animals/cow/OIP-SEGxqcuQA3ntEXP2r2N6uQHaFn.jpeg
#   inflating: ./Animals/cow/OIP-sEj3Pl6aQIsYeI8FnC6T6wHaFj.jpeg
#   inflating: ./Animals/cow/OIP-sF10sx_QvLK09LV4XI4WwAAAAA.jpeg
#   inflating: ./Animals/cow/OIP-SFL0jDAPDQc3zo9vE0k97gHaFj.jpeg
#   inflating: ./Animals/cow/OIP-sGovKcuAuie_a-P8q9VlIQHaE7.jpeg
#   inflating: ./Animals/cow/OIP-SGoZ6bzNrF19jww8_jDRIwHaFj.jpeg
#   inflating: ./Animals/cow/OIP-Sgq5pUJIrqg1WhcLWaWpsAAAAA.jpeg
#   inflating: ./Animals/cow/OIP-ShzrQyyoCohtNSLqgo44jAHaFj.jpeg
#   inflating: ./Animals/cow/OIP-SIT9Uw67dTF6wuDal0MKswHaFj.jpeg
#   inflating: ./Animals/cow/OIP-sjE-YXucyQAjADyF0l6MawHaLD.jpeg
#   inflating: ./Animals/cow/OIP-sjZPMzWql_GD8dw6m3eC7wHaGa.jpeg
#   inflating: ./Animals/cow/OIP-SKgovq18-VuqPxNBjwUq_QHaEK.jpeg
#   inflating: ./Animals/cow/OIP-sKnBuR02v78x1lqNHII-bwHaFj.jpeg
#   inflating: ./Animals/cow/OIP-SKxgltNmGKCsmsYmTDOyTwHaE0.jpeg
#   inflating: ./Animals/cow/OIP-Sm5r_H4dzBol174WeO1ecAAAAA.jpeg
#   inflating: ./Animals/cow/OIP-snj5ZRX6NGmddPeRhXUu6gHaE7.jpeg
#   inflating: ./Animals/cow/OIP-SnSrSek6up8kGrmqN1qOSwHaEc.jpeg
#   inflating: ./Animals/cow/OIP-SolYxs2cK73P1aB3tqw3iwAAAA.jpeg
#   inflating: ./Animals/cow/OIP-sP3_zcXpEObd1UEE2vDR8wHaE6.jpeg
#   inflating: ./Animals/cow/OIP-sP8ujXu1n2kWrwRMsB7bhwAAAA.jpeg
#   inflating: ./Animals/cow/OIP-sQ25Kyv8Wv2aCsCka1S95gHaC9.jpeg
#   inflating: ./Animals/cow/OIP-sqCJI0D_GaGcAl16oCVBugHaJl.jpeg
#   inflating: ./Animals/cow/OIP-sQSJG3bC0QrsmJfPhDyjsQHaDt.jpeg

# %%
import os
folder_path = '/content/Animals/cow'
folder_name = os.path.basename(folder_path)

for i, filename in enumerate(os.listdir(folder_path)):
    if filename.endswith(('.jpeg')):
        old_image_path = os.path.join(folder_path, filename)
        new_image_name = f"{folder_name}_{i+1}.jpg"
        new_image_path = os.path.join(folder_path, new_image_name)
        os.rename(old_image_path, new_image_path)

# %%
import os
folder_path = '/content/Animals/hen'
folder_name = os.path.basename(folder_path)

for i, filename in enumerate(os.listdir(folder_path)):
    if filename.endswith(('.jpeg')):
        old_image_path = os.path.join(folder_path, filename)
        new_image_name = f"{folder_name}_{i+1}.jpg"
        new_image_path = os.path.join(folder_path, new_image_name)
        os.rename(old_image_path, new_image_path)

# %%
import os
folder_path = '/content/Animals/horse'
folder_name = os.path.basename(folder_path)

for i, filename in enumerate(os.listdir(folder_path)):
    if filename.endswith(('.jpeg')):
        old_image_path = os.path.join(folder_path, filename)
        new_image_name = f"{folder_name}_{i+1}.jpg"
        new_image_path = os.path.join(folder_path, new_image_name)
        os.rename(old_image_path, new_image_path)

# %% [markdown]
# Data exploration

# %%
import os

folder_path1 = '/content/Animals/cow'
folder_path2 = '/content/Animals/hen'
folder_path3 = '/content/Animals/horse'

# List all files in the directory and filter by file extension
image_files = [f for f in os.listdir(folder_path) if f.endswith(('.jpeg', '.jpg'))]
image_files2 = [f for f in os.listdir(folder_path2) if f.endswith(('.jpeg', '.jpg'))]
image_files3 = [f for f in os.listdir(folder_path3) if f.endswith(('.jpeg', '.jpg'))]

# Count the number of images
num_images = len(image_files)
num_images2 = len(image_files2)
num_images3 = len(image_files3)

print(f"Number of images of cow: {num_images}")
print(f"Number of images of hen: {num_images2}")
print(f"Number of images of horse: {num_images3}")
# Out:
# Number of images of cow: 1451
# Number of images of hen: 1451
# Number of images of horse: 1451

# %%
import os
import shutil
from sklearn.model_selection import train_test_split

# Define the path to the combined image folder
combined_dir = '/content/Animals'

# Define the class labels
class_labels = ['cow', 'hen','horse']

# Define directories for train, and test sets
train_dir = '/content/train/'
test_dir = '/content/test/'

# Create main directories
os.makedirs(train_dir, exist_ok=True)
os.makedirs(test_dir, exist_ok=True)

# Create subdirectories for each class
for label in class_labels:
    os.makedirs(os.path.join(train_dir, label), exist_ok=True)
    os.makedirs(os.path.join(test_dir, label), exist_ok=True)

# Function to move images to respective directories
def move_images_to_class_folders():
    for label in class_labels:
        # List all files in the class directory
        class_images = [f for f in os.listdir(os.path.join(combined_dir, label)) if os.path.isfile(os.path.join(combined_dir, label, f))]

        # Split into train and test sets
        train_images, test_images = train_test_split(class_images, test_size=0.3, random_state=42)



        # Move train images
        for image in train_images:
            shutil.move(os.path.join(combined_dir, label, image), os.path.join(train_dir, label, image))

        # Move test images
        for image in test_images:
            shutil.move(os.path.join(combined_dir, label, image), os.path.join(test_dir, label, image))

# Run the function to move images
move_images_to_class_folders()

# %%
import os
import numpy as np
from sklearn.model_selection import train_test_split

# Assuming your images are labeled by folder name
def load_data(data_dir):
    X = []
    y = []
    for class_name in os.listdir(data_dir):
      class_dir = os.path.join(data_dir, class_name)
      if os.path.isdir(class_dir): #Check if it is a directory, not a file

        for image_name in os.listdir(class_dir):
            image_path = os.path.join(class_dir, image_name)
            # Load and preprocess the image (replace with your actual image loading)
            img = np.random.rand(128, 128, 3)  # Placeholder, replace with actual image loading and resizing
            X.append(img)
            y.append(class_name) #Use folder name as label
    return np.array(X), np.array(y)

# Load data from train and test directories
X_train, y_train = load_data('/content/train')
X_test, y_test = load_data('/content/test')


print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (3045, 128, 128, 3)
# (3045,)
# (1308, 128, 128, 3)
# (1308,)

# %%
import os
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import random

# Path to your training directory
train_dir = '/content/train'

# Class directories
classes = ['cow', 'hen', 'horse']

# Create a figure for plotting
fig, axes = plt.subplots(3, 3, figsize=(10, 10))

# Loop through each class and plot 3 random images
for row, class_name in enumerate(classes):
    # Get the list of files in the directory for the current class
    class_dir = os.path.join(train_dir, class_name)

    # Filter out directories and only select image files (e.g., .jpg, .png)
    image_files = [f for f in os.listdir(class_dir) if os.path.isfile(os.path.join(class_dir, f)) and f.endswith(('.jpg', '.png'))]

    # Randomly select 3 images for the current class
    selected_images = random.sample(image_files, 3)

    # Loop through the selected 3 random images for the current class
    for i, image_file in enumerate(selected_images):
        # Build the full image path
        img_path = os.path.join(class_dir, image_file)

        # Read and display the image
        img = mpimg.imread(img_path)
        axes[row, i].imshow(img)
        axes[row, i].axis('off')  # Hide the axis
        axes[row, i].set_title(f'{class_name.capitalize()} {i+1}')

# Adjust layout and show the plot
plt.tight_layout()
plt.show()

# %%
import keras
from keras import callbacks
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense, Dropout
from tensorflow.keras.optimizers import RMSprop, SGD

# %%
# Importing libraries
import tensorflow as tf
from tensorflow import keras
import numpy as np
import pandas as pd
import tensorflow_datasets as tfds
import matplotlib.pyplot as plt
from matplotlib.ticker import MaxNLocator

# %%
print(X_test.dtype)  # If X_test is a DataFrame
print(y_test.dtype)  # If y_test is a DataFrame or Series
# Out:
# float64
# <U5

# %% [markdown]
# One hot encoding

# %%
import pandas as pd
sorted(pd.DataFrame(y_train,columns=['y'])['y'].unique()) #print the classes
# Out:
# ['cow', 'hen', 'horse']

# %%
from sklearn.preprocessing import OneHotEncoder
import numpy as np
from tensorflow.keras.utils import to_categorical

# Load the train and test data
X_train, y_train = load_data('/content/train')
X_test, y_test = load_data('/content/test')


# Reshape labels to a column vector=
y_train = y_train.reshape(-1, 1)
y_test = y_test.reshape(-1, 1)

# Apply OneHotEncoder
encoder = OneHotEncoder(sparse_output=False)
y_train = encoder.fit_transform(y_train)
y_test = encoder.transform(y_test)


# Convert to NumPy arrays
X_train = np.array(X_train)
y_train = np.array(y_train)
X_test = np.array(X_test)
y_test = np.array(y_test)

print(f"Unique labels: {np.unique(y_train)}")
# Out:
# Unique labels: [0. 1.]

# %%
X_test = X_test.astype('float32')  # change data type
y_test = y_test.astype('float64')   # change data type
y_train = y_train.astype('float64') #change data type

# %%
print(X_test.dtype)
print(y_test.dtype)
# Out:
# float32
# float64

# %%
print (y_test.shape)
# Out:
# (1308, 3)

# %%
img_rows, img_cols = 128, 128

# %%
X_train = X_train.astype('float32')
X_test = X_test.astype('float32')

# Normalizing the pixel values to range [0, 1]
X_train /= 255
X_test /= 255

# Display the shape and number of samples
print('X_train shape:', X_train.shape)
print(X_train.shape[0], 'train samples')
print(X_test.shape[0], 'test samples')
# Out:
# X_train shape: (3045, 128, 128, 3)
# 3045 train samples
# 1308 test samples

# %%
print (X_train.shape)
print (y_train.shape)
print (X_test.shape)
print (y_test.shape)
# Out:
# (3045, 128, 128, 3)
# (3045, 3)
# (1308, 128, 128, 3)
# (1308, 3)

# %%
batch_size = 128 #parameters to tune on how to optimise model
num_classes = 3 #cow, hen and horse
epochs = 15 #paramters to tune on how to optimise model (how many iterations)

# %% [markdown]
# Data augmentation

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Create a data generator
datagen_train = ImageDataGenerator(
    rescale=1./255,  # rescale pixel values to [0, 1]
    rotation_range=45,  #rotate by 15 degrees
    zoom_range=0.05,   #zoom in to 5%
    width_shift_range=0.03, #shift by 3%
    height_shift_range=0.03, #shift by 3%
    horizontal_flip=True, #flip horizontally
)

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Define image preprocessing for training and validation sets
test_datagen = ImageDataGenerator(rescale=1./255)   # Same rescaling for validation data

# Define directories
train_dir = '/content/train/'  # Original training data
validation_dir = '/content/test/'  # Original validation data

# Use flow_from_directory to load the images from the original dataset
train_generator = datagen_train.flow_from_directory(
    train_dir,  # Directory containing the training data
    target_size=(128,128),  # Resize images to 128,128
    color_mode="rgb", # Use RGB color mode
    class_mode='categorical',  # Use categorical labels (multi-class classification)
)


validation_generator = test_datagen.flow_from_directory(
    validation_dir,  # Directory containing the test data
    target_size=(128,128),  # Resize images to 128x128
    color_mode="rgb",
    class_mode='categorical'  # Use categorical labels for validation
)
# Out:
# Found 3045 images belonging to 3 classes.
# Found 1308 images belonging to 3 classes.

# %%
import matplotlib.pyplot as plt
import numpy as np

# Get one batch of augmented images from the generator
augmented_images, labels = next(train_generator)

# Plot the first few augmented images
fig, axes = plt.subplots(1, 5, figsize=(15, 15))

for i in range(5):
    axes[i].imshow(augmented_images[i])  # Show the augmented image
    axes[i].axis('off')

plt.show()

# %% [markdown]
# Baseline model

# %%
model = tf.keras.Sequential()

# first set of CONV => RELU => POOL
model.add(tf.keras.layers.Conv2D(8, kernel_size=(3,3), #8 filters, so there is 8 pieces of 3 by 3 window
                        strides=(1,1), #how many pixels to use in each step
                        padding='same', # adds sufficient padding to the input so that the output has same dimension as input
                        input_shape=(128,128,3), #input shape of the image
                        use_bias=True,
                        kernel_initializer='glorot_uniform', #'glorot_uniform' define starting weights of filters
                        bias_initializer='zeros'))


model.add(tf.keras.layers.Activation('relu'))
model.add(tf.keras.layers.MaxPooling2D(pool_size=(2, 2), strides=(2, 2)))

# second set of CONV => RELU => POOL
model.add(tf.keras.layers.Conv2D(16, kernel_size=(3,3), #16 filters
                        padding='same'))
model.add(tf.keras.layers.Activation('relu'))
model.add(tf.keras.layers.MaxPooling2D(pool_size=(2, 2), strides=(2, 2))) # use 2x2 square, then take max value from the square, then move by 2 pixel to next window.


# third set of CONV => RELU => POOL
model.add(tf.keras.layers.Conv2D(32, kernel_size=(3,3), padding='same')) #32 filters
model.add(tf.keras.layers.Activation('relu'))
model.add(tf.keras.layers.MaxPooling2D(pool_size=(2, 2), strides=(2, 2)))


# fourth set of CONV => RELU => POOL

model.add(tf.keras.layers.Conv2D(64, kernel_size=(3,3), #64 filters
                        padding='same'))
model.add(tf.keras.layers.Activation('relu'))
model.add(tf.keras.layers.MaxPooling2D(pool_size=(2, 2), strides=(2, 2)))


# fifth set of CONV => RELU => POOL

model.add(tf.keras.layers.Conv2D(128, kernel_size=(3,3), #128 filters
                        padding='same'))
model.add(tf.keras.layers.Activation('relu'))
model.add(tf.keras.layers.MaxPooling2D(pool_size=(2, 2), strides=(2, 2)))

#fully connected layer
model.add(tf.keras.layers.Flatten()) #to flatten to 1D array - so that it becomes yr typical input layer for MLP
model.add(tf.keras.layers.Dense(84,activation='relu')) #fully connected layer with 84 neurons
model.add(Dropout(0.3))  # Apply Dropout

# Classifier
model.add(tf.keras.layers.Dense(num_classes)) #depends on how many unique labels

model.add(tf.keras.layers.Activation('softmax'))
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                      │ (None, 128, 128, 8)         │             224 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation (Activation)              │ (None, 128, 128, 8)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 64, 64, 8)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 64, 64, 16)          │           1,168 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation_1 (Activation)            │ (None, 64, 64, 16)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (None, 32, 32, 16)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_2 (Conv2D)                    │ (None, 32, 32, 32)          │           4,640 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation_2 (Activation)            │ (None, 32, 32, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_2 (MaxPooling2D)       │ (None, 16, 16, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_3 (Conv2D)                    │ (None, 16, 16, 64)          │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation_3 (Activation)            │ (None, 16, 16, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_3 (MaxPooling2D)       │ (None, 8, 8, 64)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_4 (Conv2D)                    │ (None, 8, 8, 128)           │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation_4 (Activation)            │ (None, 8, 8, 128)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_4 (MaxPooling2D)       │ (None, 4, 4, 128)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 2048)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 84)                  │         172,116 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 84)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 3)                   │             255 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation_5 (Activation)            │ (None, 3)                   │               0 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 270,755 (1.03 MB)
#  Trainable params: 270,755 (1.03 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(optimizer='adam',
              loss='categorical_crossentropy', #multiclass classification
              metrics=['accuracy'])

# %%
model_log = model.fit(train_generator,
                      batch_size=batch_size,
                      epochs=epochs, # number of iterations over the entire x_train data#
                      validation_data=validation_generator)
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/15
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 57s 556ms/step - accuracy: 0.3597 - loss: 1.0940 - val_accuracy: 0.4893 - val_loss: 0.9942
# Epoch 2/15
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 53s 553ms/step - accuracy: 0.4647 - loss: 1.0070 - val_accuracy: 0.5703 - val_loss: 0.8796
# Epoch 3/15
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 54s 561ms/step - accuracy: 0.5147 - loss: 0.9447 - val_accuracy: 0.5520 - val_loss: 0.9114
# Epoch 4/15
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 53s 554ms/step - accuracy: 0.5354 - loss: 0.9010 - val_accuracy: 0.6139 - val_loss: 0.7860
# Epoch 5/15
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 52s 546ms/step - accuracy: 0.5989 - loss: 0.8378 - val_accuracy: 0.6667 - val_loss: 0.7190
# Epoch 6/15
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 53s 554ms/step - accuracy: 0.6019 - loss: 0.8045 - val_accuracy: 0.6774 - val_loss: 0.6814
# Epoch 7/15
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 57s 593ms/step - accuracy: 0.6280 - loss: 0.7694 - val_accuracy: 0.6881 - val_loss: 0.6521
# Epoch 8/15
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 54s 560ms/step - accuracy: 0.6509 - loss: 0.7566 - val_accuracy: 0.6850 - val_loss: 0.6733
# Epoch 9/15
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 54s 559ms/step - accuracy: 0.6727 - loss: 0.7001 - val_accuracy: 0.6812 - val_loss: 0.6857
# Epoch 10/15
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 58s 601ms/step - accuracy: 0.6663 - loss: 0.6862 - val_accuracy: 0.7110 - val_loss: 0.6615
# Epoch 11/15
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 54s 557ms/step - accuracy: 0.6736 - loss: 0.6845 - val_accuracy: 0.7179 - val_loss: 0.6069
# Epoch 12/15
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 53s 553ms/step - accuracy: 0.7296 - loss: 0.6154 - val_accuracy: 0.7309 - val_loss: 0.5872
# Epoch 13/15
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 53s 553ms/step - accuracy: 0.7341 - loss: 0.6039 - val_accuracy: 0.7164 - val_loss: 0.6326
# Epoch 14/15
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 53s 546ms/step - accuracy: 0.7297 - loss: 0.6138 - val_accuracy: 0.7385 - val_loss: 0.5672
# Epoch 15/15
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 52s 543ms/step - accuracy: 0.7405 - loss: 0.5857 - val_accuracy: 0.7393 - val_loss: 0.5891

# %%
import matplotlib.pyplot as plt


f, (ax1, ax2) = plt.subplots(1, 2,figsize=(15,5))

ax1.plot(model_log.history['accuracy'])
ax1.plot(model_log.history['val_accuracy'])
ax1.set_title('Accuracy (Higher Better)')
ax1.set(xlabel='Epoch', ylabel='Accuracy')
ax1.legend(['train', 'validation'], loc='lower right')
ax1.xaxis.set_major_locator(MaxNLocator(integer=True))

ax2.plot(model_log.history['loss'])
ax2.plot(model_log.history['val_loss'])
ax2.set_title('Loss (Lower Better)')
ax2.set(xlabel='Epoch', ylabel='Loss')
ax2.legend(['train', 'validation'], loc='upper right')
ax2.xaxis.set_major_locator(MaxNLocator(integer=True))
#loss is useful to determine number of epochs to run. if loss flatline means enough of epochs, no need to run more.

# %% [markdown]
# Solutioning pt 2
#
#
#
#
# 1.   Three addition models (Resnet, Mobilenet, VGG16)
# 2.   Fine tuning

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Create a data generator
datagen_train = ImageDataGenerator(
    rescale=1./255,  # rescale pixel values to [0, 1]
    rotation_range=15,  #rotate by 15 degrees
    zoom_range=0.05,   #zoom in to 5%
    width_shift_range=0.03, #shift by 3%
    height_shift_range=0.03, #shift by 3%
    horizontal_flip=True, #flip horizontally
)

# %% [markdown]
# RESNET

# %%
import tensorflow as tf
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense
from tensorflow.keras.models import Model

# Load Pretrained ResNet50 without the top classification layer
pretrained_model = ResNet50(
    input_shape=(224, 224, 3),  # Input image size
    include_top=False,          # Remove fully connected layers
    weights='imagenet'          # Use pretrained ImageNet weights
)

# Freeze the base model
pretrained_model.trainable = False
num_class=3


model = tf.keras.Sequential([
    pretrained_model,
    tf.keras.layers.GlobalAveragePooling2D(), #global average pooling is used to convert feature maps to a vector (common for resnet)
    tf.keras.layers.Dense(256, activation='relu'), #classification
    tf.keras.layers.Dropout(0.3), #prevents overfitting
    tf.keras.layers.Dense(num_class, activation='softmax')

])

# Display model summary
model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 ━━━━━━━━━━━━━━━━━━━━ 4s 0us/step
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ resnet50 (Functional)                │ (None, 7, 7, 2048)          │      23,587,712 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ global_average_pooling2d             │ (None, 2048)                │               0 │
# │ (GlobalAveragePooling2D)             │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 256)                 │         524,544 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 256)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 3)                   │             771 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 24,113,027 (91.98 MB)
#  Trainable params: 525,315 (2.00 MB)
#  Non-trainable params: 23,587,712 (89.98 MB)

# %%
# Compile the model
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001),
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %%
validation_datagen = ImageDataGenerator(rescale=1./255)

train_generator = datagen_train.flow_from_directory(
    train_dir,
    target_size=(224, 224),
    batch_size=batch_size,
    class_mode='categorical',
    shuffle=True
)

validation_generator = validation_datagen.flow_from_directory(
    validation_dir,
    target_size=(224, 224),
    batch_size=batch_size,
    class_mode='categorical',
    shuffle=True
)
# Out:
# Found 3045 images belonging to 3 classes.
# Found 1308 images belonging to 3 classes.

# %%
model_log = model.fit(train_generator,
                      batch_size=batch_size,
                      epochs=epochs, # number of iterations over the entire x_train data#
                      validation_data=validation_generator)
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/15
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 736s 31s/step - accuracy: 0.3469 - loss: 1.1742 - val_accuracy: 0.3670 - val_loss: 1.0944
# Epoch 2/15
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 783s 33s/step - accuracy: 0.3673 - loss: 1.1377 - val_accuracy: 0.3937 - val_loss: 1.0901
# Epoch 3/15
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 732s 31s/step - accuracy: 0.3777 - loss: 1.1094 - val_accuracy: 0.3853 - val_loss: 1.0828
# Epoch 4/15
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 746s 31s/step - accuracy: 0.3944 - loss: 1.0888 - val_accuracy: 0.3953 - val_loss: 1.0826
# Epoch 5/15
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 735s 31s/step - accuracy: 0.3999 - loss: 1.0784 - val_accuracy: 0.3991 - val_loss: 1.0775
# Epoch 6/15
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 731s 31s/step - accuracy: 0.4185 - loss: 1.0700 - val_accuracy: 0.4083 - val_loss: 1.0742
# Epoch 7/15
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 728s 31s/step - accuracy: 0.4249 - loss: 1.0579 - val_accuracy: 0.4021 - val_loss: 1.0731
# Epoch 8/15
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 780s 33s/step - accuracy: 0.4258 - loss: 1.0535 - val_accuracy: 0.4312 - val_loss: 1.0683
# Epoch 9/15
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 725s 30s/step - accuracy: 0.4430 - loss: 1.0472 - val_accuracy: 0.4266 - val_loss: 1.0659
# Epoch 10/15
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 723s 30s/step - accuracy: 0.4345 - loss: 1.0427 - val_accuracy: 0.4098 - val_loss: 1.0683
# Epoch 11/15
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 726s 31s/step - accuracy: 0.4304 - loss: 1.0465 - val_accuracy: 0.4472 - val_loss: 1.0570
# Epoch 12/15
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 776s 33s/step - accuracy: 0.4541 - loss: 1.0405 - val_accuracy: 0.4411 - val_loss: 1.0549
# Epoch 13/15
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 724s 30s/step - accuracy: 0.4416 - loss: 1.0335 - val_accuracy: 0.4197 - val_loss: 1.0636
# Epoch 14/15
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 726s 31s/step - accuracy: 0.4640 - loss: 1.0361 - val_accuracy: 0.4335 - val_loss: 1.0477
# Epoch 15/15
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 729s 31s/step - accuracy: 0.4650 - loss: 1.0253 - val_accuracy: 0.4297 - val_loss: 1.0473

# %%
import matplotlib.pyplot as plt


f, (ax1, ax2) = plt.subplots(1, 2,figsize=(15,5))

ax1.plot(model_log.history['accuracy'])
ax1.plot(model_log.history['val_accuracy'])
ax1.set_title('Accuracy (Higher Better)')
ax1.set(xlabel='Epoch', ylabel='Accuracy')
ax1.legend(['train', 'validation'], loc='lower right')
ax1.xaxis.set_major_locator(MaxNLocator(integer=True))

ax2.plot(model_log.history['loss'])
ax2.plot(model_log.history['val_loss'])
ax2.set_title('Loss (Lower Better)')
ax2.set(xlabel='Epoch', ylabel='Loss')
ax2.legend(['train', 'validation'], loc='upper right')
ax2.xaxis.set_major_locator(MaxNLocator(integer=True))

# %% [markdown]
# MOBILENET

# %%
pretrained_model = tf.keras.applications.MobileNetV2(input_shape=(224, 224, 3), include_top=False, weights = 'imagenet')

pretrained_model.summary()
# Out:
# Model: "mobilenetv2_1.00_224"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_10            │ (None, 224, 224, 3)    │              0 │ -                      │
# │ (InputLayer)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Conv1 (Conv2D)            │ (None, 112, 112, 32)   │            864 │ input_layer_10[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ bn_Conv1                  │ (None, 112, 112, 32)   │            128 │ Conv1[0][0]            │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Conv1_relu (ReLU)         │ (None, 112, 112, 32)   │              0 │ bn_Conv1[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ expanded_conv_depthwise   │ (None, 112, 112, 32)   │            288 │ Conv1_relu[0][0]       │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ expanded_conv_depthwise_… │ (None, 112, 112, 32)   │            128 │ expanded_conv_depthwi… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ expanded_conv_depthwise_… │ (None, 112, 112, 32)   │              0 │ expanded_conv_depthwi… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ expanded_conv_project     │ (None, 112, 112, 16)   │            512 │ expanded_conv_depthwi… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ expanded_conv_project_BN  │ (None, 112, 112, 16)   │             64 │ expanded_conv_project… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_1_expand (Conv2D)   │ (None, 112, 112, 96)   │          1,536 │ expanded_conv_project… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_1_expand_BN         │ (None, 112, 112, 96)   │            384 │ block_1_expand[0][0]   │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_1_expand_relu       │ (None, 112, 112, 96)   │              0 │ block_1_expand_BN[0][… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_1_pad               │ (None, 113, 113, 96)   │              0 │ block_1_expand_relu[0… │
# │ (ZeroPadding2D)           │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_1_depthwise         │ (None, 56, 56, 96)     │            864 │ block_1_pad[0][0]      │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_1_depthwise_BN      │ (None, 56, 56, 96)     │            384 │ block_1_depthwise[0][… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_1_depthwise_relu    │ (None, 56, 56, 96)     │              0 │ block_1_depthwise_BN[… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_1_project (Conv2D)  │ (None, 56, 56, 24)     │          2,304 │ block_1_depthwise_rel… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_1_project_BN        │ (None, 56, 56, 24)     │             96 │ block_1_project[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_2_expand (Conv2D)   │ (None, 56, 56, 144)    │          3,456 │ block_1_project_BN[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_2_expand_BN         │ (None, 56, 56, 144)    │            576 │ block_2_expand[0][0]   │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_2_expand_relu       │ (None, 56, 56, 144)    │              0 │ block_2_expand_BN[0][… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_2_depthwise         │ (None, 56, 56, 144)    │          1,296 │ block_2_expand_relu[0… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_2_depthwise_BN      │ (None, 56, 56, 144)    │            576 │ block_2_depthwise[0][… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_2_depthwise_relu    │ (None, 56, 56, 144)    │              0 │ block_2_depthwise_BN[… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_2_project (Conv2D)  │ (None, 56, 56, 24)     │          3,456 │ block_2_depthwise_rel… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_2_project_BN        │ (None, 56, 56, 24)     │             96 │ block_2_project[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_2_add (Add)         │ (None, 56, 56, 24)     │              0 │ block_1_project_BN[0]… │
# │                           │                        │                │ block_2_project_BN[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_3_expand (Conv2D)   │ (None, 56, 56, 144)    │          3,456 │ block_2_add[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_3_expand_BN         │ (None, 56, 56, 144)    │            576 │ block_3_expand[0][0]   │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_3_expand_relu       │ (None, 56, 56, 144)    │              0 │ block_3_expand_BN[0][… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_3_pad               │ (None, 57, 57, 144)    │              0 │ block_3_expand_relu[0… │
# │ (ZeroPadding2D)           │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_3_depthwise         │ (None, 28, 28, 144)    │          1,296 │ block_3_pad[0][0]      │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_3_depthwise_BN      │ (None, 28, 28, 144)    │            576 │ block_3_depthwise[0][… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_3_depthwise_relu    │ (None, 28, 28, 144)    │              0 │ block_3_depthwise_BN[… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_3_project (Conv2D)  │ (None, 28, 28, 32)     │          4,608 │ block_3_depthwise_rel… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_3_project_BN        │ (None, 28, 28, 32)     │            128 │ block_3_project[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_4_expand (Conv2D)   │ (None, 28, 28, 192)    │          6,144 │ block_3_project_BN[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_4_expand_BN         │ (None, 28, 28, 192)    │            768 │ block_4_expand[0][0]   │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_4_expand_relu       │ (None, 28, 28, 192)    │              0 │ block_4_expand_BN[0][… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_4_depthwise         │ (None, 28, 28, 192)    │          1,728 │ block_4_expand_relu[0… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_4_depthwise_BN      │ (None, 28, 28, 192)    │            768 │ block_4_depthwise[0][… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_4_depthwise_relu    │ (None, 28, 28, 192)    │              0 │ block_4_depthwise_BN[… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_4_project (Conv2D)  │ (None, 28, 28, 32)     │          6,144 │ block_4_depthwise_rel… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_4_project_BN        │ (None, 28, 28, 32)     │            128 │ block_4_project[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_4_add (Add)         │ (None, 28, 28, 32)     │              0 │ block_3_project_BN[0]… │
# │                           │                        │                │ block_4_project_BN[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_5_expand (Conv2D)   │ (None, 28, 28, 192)    │          6,144 │ block_4_add[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_5_expand_BN         │ (None, 28, 28, 192)    │            768 │ block_5_expand[0][0]   │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_5_expand_relu       │ (None, 28, 28, 192)    │              0 │ block_5_expand_BN[0][… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_5_depthwise         │ (None, 28, 28, 192)    │          1,728 │ block_5_expand_relu[0… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_5_depthwise_BN      │ (None, 28, 28, 192)    │            768 │ block_5_depthwise[0][… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_5_depthwise_relu    │ (None, 28, 28, 192)    │              0 │ block_5_depthwise_BN[… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_5_project (Conv2D)  │ (None, 28, 28, 32)     │          6,144 │ block_5_depthwise_rel… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_5_project_BN        │ (None, 28, 28, 32)     │            128 │ block_5_project[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_5_add (Add)         │ (None, 28, 28, 32)     │              0 │ block_4_add[0][0],     │
# │                           │                        │                │ block_5_project_BN[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_6_expand (Conv2D)   │ (None, 28, 28, 192)    │          6,144 │ block_5_add[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_6_expand_BN         │ (None, 28, 28, 192)    │            768 │ block_6_expand[0][0]   │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_6_expand_relu       │ (None, 28, 28, 192)    │              0 │ block_6_expand_BN[0][… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_6_pad               │ (None, 29, 29, 192)    │              0 │ block_6_expand_relu[0… │
# │ (ZeroPadding2D)           │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_6_depthwise         │ (None, 14, 14, 192)    │          1,728 │ block_6_pad[0][0]      │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_6_depthwise_BN      │ (None, 14, 14, 192)    │            768 │ block_6_depthwise[0][… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_6_depthwise_relu    │ (None, 14, 14, 192)    │              0 │ block_6_depthwise_BN[… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_6_project (Conv2D)  │ (None, 14, 14, 64)     │         12,288 │ block_6_depthwise_rel… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_6_project_BN        │ (None, 14, 14, 64)     │            256 │ block_6_project[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_7_expand (Conv2D)   │ (None, 14, 14, 384)    │         24,576 │ block_6_project_BN[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_7_expand_BN         │ (None, 14, 14, 384)    │          1,536 │ block_7_expand[0][0]   │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_7_expand_relu       │ (None, 14, 14, 384)    │              0 │ block_7_expand_BN[0][… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_7_depthwise         │ (None, 14, 14, 384)    │          3,456 │ block_7_expand_relu[0… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_7_depthwise_BN      │ (None, 14, 14, 384)    │          1,536 │ block_7_depthwise[0][… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_7_depthwise_relu    │ (None, 14, 14, 384)    │              0 │ block_7_depthwise_BN[… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_7_project (Conv2D)  │ (None, 14, 14, 64)     │         24,576 │ block_7_depthwise_rel… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_7_project_BN        │ (None, 14, 14, 64)     │            256 │ block_7_project[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_7_add (Add)         │ (None, 14, 14, 64)     │              0 │ block_6_project_BN[0]… │
# │                           │                        │                │ block_7_project_BN[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_8_expand (Conv2D)   │ (None, 14, 14, 384)    │         24,576 │ block_7_add[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_8_expand_BN         │ (None, 14, 14, 384)    │          1,536 │ block_8_expand[0][0]   │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_8_expand_relu       │ (None, 14, 14, 384)    │              0 │ block_8_expand_BN[0][… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_8_depthwise         │ (None, 14, 14, 384)    │          3,456 │ block_8_expand_relu[0… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_8_depthwise_BN      │ (None, 14, 14, 384)    │          1,536 │ block_8_depthwise[0][… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_8_depthwise_relu    │ (None, 14, 14, 384)    │              0 │ block_8_depthwise_BN[… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_8_project (Conv2D)  │ (None, 14, 14, 64)     │         24,576 │ block_8_depthwise_rel… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_8_project_BN        │ (None, 14, 14, 64)     │            256 │ block_8_project[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_8_add (Add)         │ (None, 14, 14, 64)     │              0 │ block_7_add[0][0],     │
# │                           │                        │                │ block_8_project_BN[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_9_expand (Conv2D)   │ (None, 14, 14, 384)    │         24,576 │ block_8_add[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_9_expand_BN         │ (None, 14, 14, 384)    │          1,536 │ block_9_expand[0][0]   │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_9_expand_relu       │ (None, 14, 14, 384)    │              0 │ block_9_expand_BN[0][… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_9_depthwise         │ (None, 14, 14, 384)    │          3,456 │ block_9_expand_relu[0… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_9_depthwise_BN      │ (None, 14, 14, 384)    │          1,536 │ block_9_depthwise[0][… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_9_depthwise_relu    │ (None, 14, 14, 384)    │              0 │ block_9_depthwise_BN[… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_9_project (Conv2D)  │ (None, 14, 14, 64)     │         24,576 │ block_9_depthwise_rel… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_9_project_BN        │ (None, 14, 14, 64)     │            256 │ block_9_project[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_9_add (Add)         │ (None, 14, 14, 64)     │              0 │ block_8_add[0][0],     │
# │                           │                        │                │ block_9_project_BN[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_10_expand (Conv2D)  │ (None, 14, 14, 384)    │         24,576 │ block_9_add[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_10_expand_BN        │ (None, 14, 14, 384)    │          1,536 │ block_10_expand[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_10_expand_relu      │ (None, 14, 14, 384)    │              0 │ block_10_expand_BN[0]… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_10_depthwise        │ (None, 14, 14, 384)    │          3,456 │ block_10_expand_relu[… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_10_depthwise_BN     │ (None, 14, 14, 384)    │          1,536 │ block_10_depthwise[0]… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_10_depthwise_relu   │ (None, 14, 14, 384)    │              0 │ block_10_depthwise_BN… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_10_project (Conv2D) │ (None, 14, 14, 96)     │         36,864 │ block_10_depthwise_re… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_10_project_BN       │ (None, 14, 14, 96)     │            384 │ block_10_project[0][0] │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_11_expand (Conv2D)  │ (None, 14, 14, 576)    │         55,296 │ block_10_project_BN[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_11_expand_BN        │ (None, 14, 14, 576)    │          2,304 │ block_11_expand[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_11_expand_relu      │ (None, 14, 14, 576)    │              0 │ block_11_expand_BN[0]… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_11_depthwise        │ (None, 14, 14, 576)    │          5,184 │ block_11_expand_relu[… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_11_depthwise_BN     │ (None, 14, 14, 576)    │          2,304 │ block_11_depthwise[0]… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_11_depthwise_relu   │ (None, 14, 14, 576)    │              0 │ block_11_depthwise_BN… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_11_project (Conv2D) │ (None, 14, 14, 96)     │         55,296 │ block_11_depthwise_re… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_11_project_BN       │ (None, 14, 14, 96)     │            384 │ block_11_project[0][0] │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_11_add (Add)        │ (None, 14, 14, 96)     │              0 │ block_10_project_BN[0… │
# │                           │                        │                │ block_11_project_BN[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_12_expand (Conv2D)  │ (None, 14, 14, 576)    │         55,296 │ block_11_add[0][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_12_expand_BN        │ (None, 14, 14, 576)    │          2,304 │ block_12_expand[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_12_expand_relu      │ (None, 14, 14, 576)    │              0 │ block_12_expand_BN[0]… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_12_depthwise        │ (None, 14, 14, 576)    │          5,184 │ block_12_expand_relu[… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_12_depthwise_BN     │ (None, 14, 14, 576)    │          2,304 │ block_12_depthwise[0]… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_12_depthwise_relu   │ (None, 14, 14, 576)    │              0 │ block_12_depthwise_BN… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_12_project (Conv2D) │ (None, 14, 14, 96)     │         55,296 │ block_12_depthwise_re… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_12_project_BN       │ (None, 14, 14, 96)     │            384 │ block_12_project[0][0] │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_12_add (Add)        │ (None, 14, 14, 96)     │              0 │ block_11_add[0][0],    │
# │                           │                        │                │ block_12_project_BN[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_13_expand (Conv2D)  │ (None, 14, 14, 576)    │         55,296 │ block_12_add[0][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_13_expand_BN        │ (None, 14, 14, 576)    │          2,304 │ block_13_expand[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_13_expand_relu      │ (None, 14, 14, 576)    │              0 │ block_13_expand_BN[0]… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_13_pad              │ (None, 15, 15, 576)    │              0 │ block_13_expand_relu[… │
# │ (ZeroPadding2D)           │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_13_depthwise        │ (None, 7, 7, 576)      │          5,184 │ block_13_pad[0][0]     │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_13_depthwise_BN     │ (None, 7, 7, 576)      │          2,304 │ block_13_depthwise[0]… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_13_depthwise_relu   │ (None, 7, 7, 576)      │              0 │ block_13_depthwise_BN… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_13_project (Conv2D) │ (None, 7, 7, 160)      │         92,160 │ block_13_depthwise_re… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_13_project_BN       │ (None, 7, 7, 160)      │            640 │ block_13_project[0][0] │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_14_expand (Conv2D)  │ (None, 7, 7, 960)      │        153,600 │ block_13_project_BN[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_14_expand_BN        │ (None, 7, 7, 960)      │          3,840 │ block_14_expand[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_14_expand_relu      │ (None, 7, 7, 960)      │              0 │ block_14_expand_BN[0]… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_14_depthwise        │ (None, 7, 7, 960)      │          8,640 │ block_14_expand_relu[… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_14_depthwise_BN     │ (None, 7, 7, 960)      │          3,840 │ block_14_depthwise[0]… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_14_depthwise_relu   │ (None, 7, 7, 960)      │              0 │ block_14_depthwise_BN… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_14_project (Conv2D) │ (None, 7, 7, 160)      │        153,600 │ block_14_depthwise_re… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_14_project_BN       │ (None, 7, 7, 160)      │            640 │ block_14_project[0][0] │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_14_add (Add)        │ (None, 7, 7, 160)      │              0 │ block_13_project_BN[0… │
# │                           │                        │                │ block_14_project_BN[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_15_expand (Conv2D)  │ (None, 7, 7, 960)      │        153,600 │ block_14_add[0][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_15_expand_BN        │ (None, 7, 7, 960)      │          3,840 │ block_15_expand[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_15_expand_relu      │ (None, 7, 7, 960)      │              0 │ block_15_expand_BN[0]… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_15_depthwise        │ (None, 7, 7, 960)      │          8,640 │ block_15_expand_relu[… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_15_depthwise_BN     │ (None, 7, 7, 960)      │          3,840 │ block_15_depthwise[0]… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_15_depthwise_relu   │ (None, 7, 7, 960)      │              0 │ block_15_depthwise_BN… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_15_project (Conv2D) │ (None, 7, 7, 160)      │        153,600 │ block_15_depthwise_re… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_15_project_BN       │ (None, 7, 7, 160)      │            640 │ block_15_project[0][0] │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_15_add (Add)        │ (None, 7, 7, 160)      │              0 │ block_14_add[0][0],    │
# │                           │                        │                │ block_15_project_BN[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_16_expand (Conv2D)  │ (None, 7, 7, 960)      │        153,600 │ block_15_add[0][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_16_expand_BN        │ (None, 7, 7, 960)      │          3,840 │ block_16_expand[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_16_expand_relu      │ (None, 7, 7, 960)      │              0 │ block_16_expand_BN[0]… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_16_depthwise        │ (None, 7, 7, 960)      │          8,640 │ block_16_expand_relu[… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_16_depthwise_BN     │ (None, 7, 7, 960)      │          3,840 │ block_16_depthwise[0]… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_16_depthwise_relu   │ (None, 7, 7, 960)      │              0 │ block_16_depthwise_BN… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_16_project (Conv2D) │ (None, 7, 7, 320)      │        307,200 │ block_16_depthwise_re… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_16_project_BN       │ (None, 7, 7, 320)      │          1,280 │ block_16_project[0][0] │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Conv_1 (Conv2D)           │ (None, 7, 7, 1280)     │        409,600 │ block_16_project_BN[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Conv_1_bn                 │ (None, 7, 7, 1280)     │          5,120 │ Conv_1[0][0]           │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ out_relu (ReLU)           │ (None, 7, 7, 1280)     │              0 │ Conv_1_bn[0][0]        │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 2,257,984 (8.61 MB)
#  Trainable params: 2,223,872 (8.48 MB)
#  Non-trainable params: 34,112 (133.25 KB)

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Define image preprocessing for training and validation sets
test_datagen = ImageDataGenerator(rescale=1./255)   # Same rescaling for validation data

# Define directories
train_dir = '/content/train/'  # Original training data
validation_dir = '/content/test/'  # Original validation data

# Use flow_from_directory to load the images from the original dataset
train_generator = datagen_train.flow_from_directory(
    train_dir,  # Directory containing the training data
    target_size=(224,224),  # Resize images to 224,224
    color_mode="rgb", # Use RGB color mode
    class_mode='categorical',  # Use categorical labels (multi-class classification)
    shuffle=True
)


validation_generator = test_datagen.flow_from_directory(
    validation_dir,  # Directory containing the test data
    target_size=(224,224),  # Resize images to 224,224
    color_mode="rgb",
    class_mode='categorical'  # Use categorical labels for validation
)
# Out:
# Found 3045 images belonging to 3 classes.
# Found 1308 images belonging to 3 classes.

# %%
# Freeze the Pre-Trained Model - #MLP
pretrained_model.trainable = False
num_class = 3

# Create a tf.keras.Sequential model, and add the pre-trained model and the new classification layer
model2 = tf.keras.Sequential([
    pretrained_model,
    tf.keras.layers.Flatten(), #want 1D pictures
    tf.keras.layers.Dense(256, activation='relu'), #classification
    tf.keras.layers.Dropout(0.3),
    tf.keras.layers.Dense(num_class, activation='softmax')

])

# %%
model2.summary()
# Out:
# Model: "sequential_10"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ mobilenetv2_1.00_224 (Functional)    │ (None, 7, 7, 1280)          │       2,257,984 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten_9 (Flatten)                  │ (None, 62720)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_20 (Dense)                     │ (None, 256)                 │      16,056,576 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_10 (Dropout)                 │ (None, 256)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_21 (Dense)                     │ (None, 3)                   │             771 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 18,315,331 (69.87 MB)
#  Trainable params: 16,057,347 (61.25 MB)
#  Non-trainable params: 2,257,984 (8.61 MB)

# %%
model2.compile(
  optimizer='adam',
  loss='categorical_crossentropy',
  metrics=['accuracy'])

# %%
model_log = model2.fit(train_generator,
                    batch_size=batch_size,
                    epochs=epochs,
                    validation_data=validation_generator)
# Out:
# Epoch 1/15
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 236s 2s/step - accuracy: 0.8548 - loss: 3.0633 - val_accuracy: 0.9228 - val_loss: 0.7320
# Epoch 2/15
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 255s 3s/step - accuracy: 0.9319 - loss: 0.7897 - val_accuracy: 0.9557 - val_loss: 0.2289
# Epoch 3/15
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 253s 3s/step - accuracy: 0.9637 - loss: 0.2145 - val_accuracy: 0.9625 - val_loss: 0.1481
# Epoch 4/15
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 255s 3s/step - accuracy: 0.9671 - loss: 0.1051 - val_accuracy: 0.9610 - val_loss: 0.1945
# Epoch 5/15
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 223s 2s/step - accuracy: 0.9659 - loss: 0.1240 - val_accuracy: 0.9557 - val_loss: 0.1906
# Epoch 6/15
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 223s 2s/step - accuracy: 0.9611 - loss: 0.1020 - val_accuracy: 0.9618 - val_loss: 0.1733
# Epoch 7/15
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 224s 2s/step - accuracy: 0.9741 - loss: 0.0713 - val_accuracy: 0.9595 - val_loss: 0.1332
# Epoch 8/15
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 225s 2s/step - accuracy: 0.9798 - loss: 0.0678 - val_accuracy: 0.9557 - val_loss: 0.2280
# Epoch 9/15
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 262s 2s/step - accuracy: 0.9742 - loss: 0.1419 - val_accuracy: 0.9687 - val_loss: 0.1453
# Epoch 10/15
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 224s 2s/step - accuracy: 0.9808 - loss: 0.0670 - val_accuracy: 0.9671 - val_loss: 0.1759
# Epoch 11/15
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 230s 2s/step - accuracy: 0.9840 - loss: 0.0602 - val_accuracy: 0.9641 - val_loss: 0.1786
# Epoch 12/15
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 251s 3s/step - accuracy: 0.9853 - loss: 0.0425 - val_accuracy: 0.9534 - val_loss: 0.1934
# Epoch 13/15
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 225s 2s/step - accuracy: 0.9853 - loss: 0.0477 - val_accuracy: 0.9687 - val_loss: 0.1822
# Epoch 14/15
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 233s 2s/step - accuracy: 0.9831 - loss: 0.0508 - val_accuracy: 0.9664 - val_loss: 0.1433
# Epoch 15/15
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 259s 3s/step - accuracy: 0.9817 - loss: 0.0634 - val_accuracy: 0.9641 - val_loss: 0.1381

# %%
import matplotlib.pyplot as plt


f, (ax1, ax2) = plt.subplots(1, 2,figsize=(15,5))

ax1.plot(model_log.history['accuracy'])
ax1.plot(model_log.history['val_accuracy'])
ax1.set_title('Accuracy (Higher Better)')
ax1.set(xlabel='Epoch', ylabel='Accuracy')
ax1.legend(['train', 'validation'], loc='lower right')
ax1.xaxis.set_major_locator(MaxNLocator(integer=True))

ax2.plot(model_log.history['loss'])
ax2.plot(model_log.history['val_loss'])
ax2.set_title('Loss (Lower Better)')
ax2.set(xlabel='Epoch', ylabel='Loss')
ax2.legend(['train', 'validation'], loc='upper right')
ax2.xaxis.set_major_locator(MaxNLocator(integer=True))

# %% [markdown]
# VGG 16

# %%
from tensorflow.keras.applications import VGG16
from tensorflow.keras.models import Model

# Load the VGG16 model pre-trained on ImageNet
model3 = VGG16(weights="imagenet", include_top=False, input_shape=(224, 224, 3))

# %%
model3.summary()
# Out:
# Model: "vgg16"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer_16 (InputLayer)          │ (None, 224, 224, 3)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block1_conv1 (Conv2D)                │ (None, 224, 224, 64)        │           1,792 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block1_conv2 (Conv2D)                │ (None, 224, 224, 64)        │          36,928 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block1_pool (MaxPooling2D)           │ (None, 112, 112, 64)        │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block2_conv1 (Conv2D)                │ (None, 112, 112, 128)       │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block2_conv2 (Conv2D)                │ (None, 112, 112, 128)       │         147,584 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block2_pool (MaxPooling2D)           │ (None, 56, 56, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block3_conv1 (Conv2D)                │ (None, 56, 56, 256)         │         295,168 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block3_conv2 (Conv2D)                │ (None, 56, 56, 256)         │         590,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block3_conv3 (Conv2D)                │ (None, 56, 56, 256)         │         590,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block3_pool (MaxPooling2D)           │ (None, 28, 28, 256)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block4_conv1 (Conv2D)                │ (None, 28, 28, 512)         │       1,180,160 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block4_conv2 (Conv2D)                │ (None, 28, 28, 512)         │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block4_conv3 (Conv2D)                │ (None, 28, 28, 512)         │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block4_pool (MaxPooling2D)           │ (None, 14, 14, 512)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block5_conv1 (Conv2D)                │ (None, 14, 14, 512)         │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block5_conv2 (Conv2D)                │ (None, 14, 14, 512)         │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block5_conv3 (Conv2D)                │ (None, 14, 14, 512)         │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block5_pool (MaxPooling2D)           │ (None, 7, 7, 512)           │               0 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 14,714,688 (56.13 MB)
#  Trainable params: 14,714,688 (56.13 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Freeze the Pre-Trained Model - #MLP
pretrained_model.trainable = False
num_class = 3

# Create a tf.keras.Sequential model, and add the pre-trained model and the new classification layer
model3 = tf.keras.Sequential([
    pretrained_model,
    tf.keras.layers.Flatten(), #want 1D pictures
    tf.keras.layers.Dense(256, activation='relu'), #classification
    tf.keras.layers.Dropout(0.3),
    tf.keras.layers.Dense(num_class, activation='softmax')

])

# %%
model3.compile(
  optimizer='adam',
  loss='categorical_crossentropy',
  metrics=['accuracy'])

# %%
model_log = model3.fit(train_generator,
                    batch_size=batch_size,
                    epochs=epochs,
                    validation_data=validation_generator)
# Out:
# Epoch 1/15
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 238s 2s/step - accuracy: 0.8443 - loss: 3.1447 - val_accuracy: 0.9404 - val_loss: 0.1604
# Epoch 2/15
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 256s 2s/step - accuracy: 0.9414 - loss: 0.1632 - val_accuracy: 0.9595 - val_loss: 0.1454
# Epoch 3/15
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 225s 2s/step - accuracy: 0.9570 - loss: 0.1318 - val_accuracy: 0.9434 - val_loss: 0.1899
# Epoch 4/15
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 255s 3s/step - accuracy: 0.9583 - loss: 0.1226 - val_accuracy: 0.9625 - val_loss: 0.1541
# Epoch 5/15
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 230s 2s/step - accuracy: 0.9597 - loss: 0.1271 - val_accuracy: 0.9625 - val_loss: 0.1626
# Epoch 6/15
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 225s 2s/step - accuracy: 0.9656 - loss: 0.1325 - val_accuracy: 0.9595 - val_loss: 0.1691
# Epoch 7/15
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 223s 2s/step - accuracy: 0.9567 - loss: 0.1211 - val_accuracy: 0.9595 - val_loss: 0.1382
# Epoch 8/15
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 253s 3s/step - accuracy: 0.9700 - loss: 0.1167 - val_accuracy: 0.9465 - val_loss: 0.2144
# Epoch 9/15
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 224s 2s/step - accuracy: 0.9701 - loss: 0.0841 - val_accuracy: 0.9641 - val_loss: 0.1421
# Epoch 10/15
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 221s 2s/step - accuracy: 0.9792 - loss: 0.0579 - val_accuracy: 0.9633 - val_loss: 0.1705
# Epoch 11/15
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 222s 2s/step - accuracy: 0.9780 - loss: 0.0482 - val_accuracy: 0.9679 - val_loss: 0.1603
# Epoch 12/15
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 224s 2s/step - accuracy: 0.9814 - loss: 0.0548 - val_accuracy: 0.9602 - val_loss: 0.2613
# Epoch 13/15
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 223s 2s/step - accuracy: 0.9719 - loss: 0.0923 - val_accuracy: 0.9633 - val_loss: 0.1482
# Epoch 14/15
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 222s 2s/step - accuracy: 0.9730 - loss: 0.0721 - val_accuracy: 0.9664 - val_loss: 0.1671
# Epoch 15/15
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 223s 2s/step - accuracy: 0.9771 - loss: 0.0640 - val_accuracy: 0.9618 - val_loss: 0.1699

# %%
import matplotlib.pyplot as plt


f, (ax1, ax2) = plt.subplots(1, 2,figsize=(15,5))

ax1.plot(model_log.history['accuracy'])
ax1.plot(model_log.history['val_accuracy'])
ax1.set_title('Accuracy (Higher Better)')
ax1.set(xlabel='Epoch', ylabel='Accuracy')
ax1.legend(['train', 'validation'], loc='lower right')
ax1.xaxis.set_major_locator(MaxNLocator(integer=True))

ax2.plot(model_log.history['loss'])
ax2.plot(model_log.history['val_loss'])
ax2.set_title('Loss (Lower Better)')
ax2.set(xlabel='Epoch', ylabel='Loss')
ax2.legend(['train', 'validation'], loc='upper right')
ax2.xaxis.set_major_locator(MaxNLocator(integer=True))

# %% [markdown]
# Grid Search

# %%
from sklearn.model_selection import ParameterGrid

param_grid = {
    'units': [128,256, 512],
    'dropout': [0.4, 0.5],
    'learning_rate': [0.001, 0.0005]
}

for params in ParameterGrid(param_grid):
    model = tf.keras.Sequential([
        pretrained_model,
        tf.keras.layers.Flatten(),
        tf.keras.layers.Dense(params['units'], activation='relu'),
        tf.keras.layers.Dropout(params['dropout']),
        tf.keras.layers.Dense(num_class, activation='softmax')
    ])
    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
    model.fit(train_generator, epochs=5, validation_data=validation_generator)

# %% [markdown]
# Fine Tuning
